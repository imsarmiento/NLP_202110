# %% [markdown]
# # Punto 1 - Italian
# ## Automatic identification of “trending/viral” topics around COVID in time in the World using deep learning architectures. Type: Different approaches.

# %%
import pickle as pk
import pandas as pd
import numpy as np
import json
from sklearn.feature_extraction.text import CountVectorizer
from stop_words import get_stop_words
import umap.umap_ as umap

# %% [markdown]
# ## Files used
# The datasets and the embedings generated with a pretrained Sentence Bert model

# %%
#prefix = './drive/MyDrive/'
prefix = ''
italian_path = prefix + 'datasets/italian/italian_out_hash_bien.json'

#prefix = './drive/MyDrive/'
prefix = ''
italian_embeddings_path = prefix + 'models_hpc/embeddings_ita_v2.pickle'

#prefix = './drive/MyDrive/'
prefix = ''
umap_italian_embeddings_path = prefix + 'models_hpc/umap_ita_v2.pickle'

# %%
file = open(italian_path, 'r')
data = []
for line in file:
    data.append(json.loads(line))
text_raw_df = pd.json_normalize(data)

print(text_raw_df.shape)
text_raw_df.head(10)
# Out:
# (814485, 4)
#                     id  publication_date   source  \
# 0  1324811856859533313      1.604695e+09  twitter
# 1  1288746494368124928      1.596096e+09  twitter
# 2  1326191597785059329      1.605024e+09  twitter
# 3  1275134048722132993      1.592851e+09  twitter
# 4  1243118079091118080      1.585217e+09  twitter
# 5  1267645840455278594      1.591065e+09  twitter
# 6  1233340720460726272      1.582886e+09  twitter
# 7  1279712208612667393      1.593942e+09  twitter
# 8  1271709738301095936      1.592034e+09  twitter
# 9  1296853994686513152      1.598029e+09  twitter
#
#                                                 text
# 0  Il prof. #Galli è molto preoccupato da quanto ...
# 1  Il COVID-19 coincide con un momento cruciale n...
# 2  Muoviamoci #vaccinoCovid #coronavirus #COVID19...
# 3  @mosllerdd @Cartabellotta Si sarebbero potute ...
# 4  @morzo6 @CNN Purtroppo sì. State a casa. Disin...
# 5  @orticArya * "il coronavirus non c'è più, ma c...
# 6  Coronavirus, l’ultima trovata: mascherine grif...
# 7  "Penne in quarantena". Tredici #racconti di al...
# 8  Cina, torna l’incubo Coronavirus: alcuni quart...
# 9                                 Questo è il punto

# %%
'''
Turn text to Numpy Array
'''
texts_column = text_raw_df.loc[:,'text']
raw_texts = texts_column.values
raw_texts[0]
# Out:
# 'Il prof. #Galli è molto preoccupato da quanto sta accadendo a #Milano '

# %%
#with open(italian_embeddings_path, "rb") as output_file:
#    embeddings = pk.load(output_file)

with open(umap_italian_embeddings_path, "rb") as output_file:
    umap_embeddings = pk.load(output_file)

# %% [markdown]
# ### HDBSCAN para el clustering

# %%
import hdbscan
cluster = hdbscan.HDBSCAN(min_cluster_size=70,
                          metric='euclidean',
                          cluster_selection_method='eom',
                          min_samples=500).fit(umap_embeddings)

# %% [markdown]
# ### Visualisación de los clusters

# %%
import matplotlib.pyplot as plt

# Prepare data
umap_data = umap.UMAP(n_neighbors=30, n_components=2, min_dist=0.0, metric='cosine').fit_transform(umap_embeddings)
result = pd.DataFrame(umap_data, columns=['x', 'y'])
result['labels'] = cluster.labels_

# Visualize clusters
fig, ax = plt.subplots(figsize=(20, 10))
outliers = result.loc[result.labels == -1, :]
clustered = result.loc[result.labels != -1, :]
plt.scatter(outliers.x, outliers.y, color='#BDBDBD', s=0.05)
plt.scatter(clustered.x, clustered.y, c=clustered.labels, s=0.05, cmap='hsv_r')
plt.colorbar()

# %% [markdown]
# ### c-TF-IDF

# %%
docs_df = pd.DataFrame(raw_texts, columns=["Doc"])
docs_df['Topic'] = cluster.labels_
docs_df['Doc_ID'] = range(len(docs_df))
docs_per_topic = docs_df.groupby(['Topic'], as_index = False).agg({'Doc': ' '.join})

# %%
def c_tf_idf(documents, m, ngram_range=(1, 1)):
    count = CountVectorizer(ngram_range=ngram_range, stop_words=get_stop_words('italian')).fit(documents)
    t = count.transform(documents).toarray()
    w = t.sum(axis=1)
    tf = np.divide(t.T, w)
    sum_t = t.sum(axis=0)
    idf = np.log(np.divide(m, sum_t)).reshape(-1, 1)
    tf_idf = np.multiply(tf, idf)

    return tf_idf, count

tf_idf, count = c_tf_idf(docs_per_topic.Doc.values, m=len(raw_texts))

# %%
def extract_top_n_words_per_topic(tf_idf, count, docs_per_topic, n=20):
    words = count.get_feature_names()
    labels = list(docs_per_topic.Topic)
    tf_idf_transposed = tf_idf.T
    indices = tf_idf_transposed.argsort()[:, -n:]
    top_n_words = {label: [(words[j], tf_idf_transposed[i][j]) for j in indices[i]][::-1] for i, label in enumerate(labels)}
    return top_n_words

def extract_topic_sizes(df):
    topic_sizes = (df.groupby(['Topic'])
                     .Doc
                     .count()
                     .reset_index()
                     .rename({"Topic": "Topic", "Doc": "Size"}, axis='columns')
                     .sort_values("Size", ascending=False))
    return topic_sizes

top_n_words = extract_top_n_words_per_topic(tf_idf, count, docs_per_topic, n=20)
topic_sizes = extract_topic_sizes(docs_df);
topic_sizes.head(10)
# Out:
#      Topic    Size
# 0       -1  557212
# 104    103   11999
# 333    332   11279
# 279    278    7076
# 210    209    6888
# 360    359    6745
# 367    366    5424
# 370    369    5203
# 160    159    5065
# 68      67    4926

# %%
len(topic_sizes)

# %%
for topic in topic_sizes['Topic']:
  if topic == -1:
    continue
  print('Topic #' + str(topic) +":"+ '\n')
  print(str([t[0] for t in top_n_words[topic][:10]]) + '\n')
# Out:
# Topic #154:
#
# ['cina', 'cinese', 'cinesi', 'coronavirus', 'pechino', 'wuhan', 'china', 'italia', 'virus', 'oms']
#
# Topic #221:
#
# ['scuole', 'scuola', 'chiuse', 'coronavirus', 'studenti', 'azzolina', 'chiusura', 'università', 'lezioni', 'classe']
#
# Topic #391:
#
# ['calcio', 'serie', 'sport', 'coronavirus', 'campionato', 'seriea', 'positivo', 'inter', 'giocatori', 'porte']
#
# Topic #408:
#
# ['vaccino', 'vaccini', 'covid19', 'covid', '19', 'anti', 'vaccine', 'vaccinazione', 'vaccinoanticovid', 'vaccinocovid']
#
# Topic #410:
#
# ['coronavirus', 'conte', 'salvini', 'governo', 'emergenza', 'misure', 'italia', 'decreto', 'via', 'speranza']
#
# Topic #356:
#
# ['covid19', '19', 'covid', 'solo', 'cosa', 'covid_19', 'fatto', 'esiste', 'prima', 'quando']
#
# Topic #461:
#
# ['coronavirus', 'matteosalvinimi', 'solo', 'prima', 'fatto', 'poi', 'già', 'sempre', 'fa', 'ora']
#
# Topic #459:
#
# ['morti', 'nuovi', 'casi', 'bollettino', 'italia', 'oggi', '24', 'contagi', 'ultime', 'coronavirus']
#
# Topic #132:
#
# ['trump', 'usa', 'biden', 'donald', 'coronavirus', 'presidente', 'covid19', 'bianca', 'fauci', 'mondo']
#
# Topic #173:
#
# ['coronavirus', 'abruzzo', 'emergenza', 'governo', 'basilicata', 'piu', 'de', 'regione', 'fi', 'contagi']
#
# Topic #355:
#
# ['19', 'covid', 'emergenza', 'covid19', 'crisi', 'impatto', 'lavoro', 'tempi', 'post', 'economia']
#
# Topic #389:
#
# ['19', 'covid', 'positivo', 'positivi', 'covid19', 'positività', 'squadra', 'gruppo', 'risultato', 'giocatori']
#
# Topic #105:
#
# ['piemonte', 'contagi', 'coronavirus', 'bollettino', 'nuovi', 'decessi', 'guariti', 'regione', 'casi', 'cirio']
#
# Topic #305:
#
# ['medici', 'medico', 'sanità', 'ospedali', 'salute', 'infermieri', 'sanitario', 'sanitaria', 'sanitari', 'ospedale']
#
# Topic #464:
#
# ['positivi', 'nuovi', 'campania', 'coronavirus', 'tamponi', 'positivo', 'casi', 'calabria', 'oggi', 'decessi']
#
# Topic #224:
#
# ['morti', 'covid19', '000', 'morte', 'covid', 'giorno', 'persone', 'numero', 'morto', 'muore']
#
# Topic #240:
#
# ['roma', 'coronavirus', 'lazio', 'spallanzani', 'via', 'romani', 'romano', 'piazza', 'mascherine', 'raggi']
#
# Topic #304:
#
# ['mascherina', 'mascherine', 'indossare', 'covid19', 'guanti', 'aperto', 'naso', 'uso', 'obbligo', 'distanziamento']
#
# Topic #210:
#
# ['europa', 'ue', 'coronavirus', 'europea', 'europeo', 'italia', 'europei', 'unione', 'paesi', 'eurogruppo']
#
# Topic #64:
#
# ['animali', 'cani', 'cane', 'gatti', 'animale', 'coronavirus', 'carne', 'gatto', 'domestici', 'zoo']
#
# Topic #434:
#
# ['mondo', 'milioni', 'usa', 'morti', 'oltre', 'casi', 'mila', 'coronavirus', 'contagi', '000']
#
# Topic #439:
#
# ['dale', 'cuomo', 'schifo', 'illa', 'pinche', 'cazzo', 'eh', 'asco', 'maledetti', 'rico']
#
# Topic #215:
#
# ['papa', 'chiesa', 'francesco', 'vaticano', 'vatican', 'chiese', 'preghiera', 'coronavirus', 'messa', 'papafrancesco']
#
# Topic #446:
#
# ['coronavirus', 'comunque', 'cazzo', 'cosa', 'quando', 'ansia', 'raga', 'solo', 'fa', 'fatto']
#
# Topic #169:
#
# ['casi', 'positivi', 'nuovi', 'coronavirus', 'piemonte', 'bollettino', 'contagiati', 'guariti', 'abruzzo', 'dati']
#
# Topic #274:
#
# ['anni', 'morto', 'muore', 'vittima', 'donna', 'morta', 'coronavirus', 'uomo', 'ospedale', 'ricoverato']
#
# Topic #118:
#
# ['luca', 'de', 'campania', 'coronavirus', 'zaia', 'ordinanza', 'vincenzo', 'governatore', 'presidente', 'veneto']
#
# Topic #167:
#
# ['19', 'covid', 'covid19', 'emergenza', 'puglia', 'positivi', 'nuovi', 'foggia', 'casi', 'anti']
#
# Topic #227:
#
# ['lazio', 'roma', 'casi', 'nuovi', 'positivi', 'oggi', 'amato', 'coronavirus', 'contagi', 'decessi']
#
# Topic #280:
#
# ['germania', 'merkel', 'coronavirus', 'tedesco', 'berlino', 'contagi', 'tedeschi', 'casi', 'oltre', 'primo']
#
# Topic #334:
#
# ['europa', 'ue', 'europea', 'europei', 'europeo', 'unione', 'covid19', 'paesi', 'crisi', 'euro']
#
# Topic #381:
#
# ['governo', 'governodellavergogna', 'covid19', 'conte', 'contedimettiti', 'giuseppeconteit', 'cosa', 'fatto', 'stato', 'incapaci']
#
# Topic #84:
#
# ['africa', 'africani', 'egitto', 'nigeria', 'primo', 'coronavirus', 'caso', 'variante', 'sudafrica', 'covid19']
#
# Topic #75:
#
# ['russia', 'putin', 'russo', 'vaccino', 'russi', 'sputnik', 'mosca', 'russa', 'primo', 'covid19']
#
# Topic #302:
#
# ['lockdown', 'lockdown2', 'covid19', 'lockdownitalia', 'nuovo', 'dpcm', 'durante', 'mesi', 'dopo', 'conte']
#
# Topic #289:
#
# ['natale', 'ristoranti', 'bar', 'pasqua', 'covid19', 'natale2020', 'ristorante', 'dpcm', 'lockdown', 'capodanno']
#
# Topic #368:
#
# ['giuseppeconteit', 'robersperanza', 'cartabellotta', 'valy_s', 'matteosalvinimi', 'borghi_claudio', 'patriziarametta', 'giorgiameloni', 'miti_vigliero', 'robertoburioni']
#
# Topic #133:
#
# ['brasile', 'morti', 'brasiliana', 'mondo', 'variante', 'oltre', 'casi', 'coronavirus', 'usa', 'contagi']
#
# Topic #405:
#
# ['lombardia', 'milano', 'fontana', 'coronavirus', 'sala', 'contagi', 'gallera', 'regione', 'via', 'duomo']
#
# Topic #365:
#
# ['eh', 'ditto', 'sì', 'guarda', 'matteosalvinimi', 'infatti', 'eccolo', 'già', 'bene', 'così']
#
# Topic #95:
#
# ['emilia', 'romagna', 'casi', 'nuovi', 'aggiornamento', 'positivi', 'coronavirus', 'contagi', 'morti', 'bollettino']
#
# Topic #116:
#
# ['app', 'immuni', 'tracciamento', 'privacy', 'scaricare', 'immuniapp', 'download', 'contact', 'tracing', 'funziona']
#
# Topic #420:
#
# ['puglia', 'casi', 'nuovi', 'bat', 'bari', 'barese', 'positivi', 'news24city', 'decessi', 'provincia']
#
# Topic #435:
#
# ['lombardia', 'nuovi', 'morti', 'casi', 'contagi', 'milano', 'decessi', '24', 'coronavirus', 'ore']
#
# Topic #456:
#
# ['nuovi', 'casi', 'calabria', 'contagi', 'coronavirus', 'provincia', 'sardegna', 'decessi', 'guariti', 'nessun']
#
# Topic #328:
#
# ['virus', '19', 'covid', 'covid19', 'influenza', 'stagionale', 'solo', 'hiv', 'virologi', 'può']
#
# Topic #50:
#
# ['israele', 'israeliano', 'palestinesi', 'gaza', 'vaccino', 'israeliani', 'netanyahu', 'lockdown', 'covid19', 'palestina']
#
# Topic #213:
#
# ['test', 'rapidi', '19', 'covid', 'sierologici', 'covid19', 'sierologico', 'rapido', 'pcr', 'tampone']
#
# Topic #81:
#
# ['f1', 'gp', 'motogp', 'ferrari', 'formula', 'lamborghini', 'valentino', 'hamilton', 'formula1', 'rossi']
#
# Topic #55:
#
# ['johnson', 'boris', 'amp', 'vaccino', 'borisjohnson', 'premier', 'johnsonandjohnson', 'coronavirus', 'regno', 'unito']
#
# Topic #414:
#
# ['dale', 'cazzo', 'raga', 'boooo', 'madre', 'porca', 'cuomo', 'cosa', 'merda', 'amo']
#
# Topic #402:
#
# ['fase', 'coronavirus', 'maggio', 'conte', 'cosa', 'fase2', 'riapertura', 'via', 'italia', 'riaperture']
#
# Topic #416:
#
# ['test', 'sierologici', 'rapidi', 'rapido', 'coronavirus', 'minuti', 'sierologico', 'via', 'tamponi', 'privati']
#
# Topic #225:
#
# ['migranti', 'immigrati', 'clandestini', 'immigrazione', 'covid19', 'italiani', 'sbarchi', 'lamorgese', 'accoglienza', 'portano']
#
# Topic #51:
#
# ['svezia', 'svedese', 'modello', 'lockdown', 'stoccolma', 'morti', 'strategia', 'norvegia', 'mortalità', 'covid19']
#
# Topic #141:
#
# ['migranti', 'immigrati', 'libia', 'coronavirus', 'immigrazione', 'quarantena', 'salvini', 'clandestini', 'governo', 'sbarchi']
#
# Topic #281:
#
# ['germania', 'merkel', 'tedeschi', 'tedesco', 'berlino', 'tedesca', 'lockdown', 'covid19', 'angela', 'italia']
#
# Topic #166:
#
# ['italia', 'italiani', 'italiano', 'coronavirus', 'europa', 'governo', 'italiana', 'tutta', 'piu', 'euro']
#
# Topic #156:
#
# ['scienza', 'scienziati', 'scientifica', 'scientifico', 'scientifiche', 'scienziato', 'scientifici', 'comunità', 'evidenze', 'politica']
#
# Topic #261:
#
# ['lombardia', 'lombardi', 'regione', 'lombardo', 'lombarda', 'sconvolsero', 'solo', 'fatto', 'regioni', 'gallera']
#
# Topic #100:
#
# ['berlusconi', 'silvio', 'positivo', 'zangrillo', 'raffaele', 'briatore', 'ricoverato', 'coronavirus', 'san', 'covid19']
#
# Topic #329:
#
# ['pandemia', 'cosa', 'inizio', 'durante', 'epidemia', 'quando', 'anno', 'dopo', 'solo', 'fatto']
#
# Topic #379:
#
# ['italia', 'italiani', 'italiano', 'popolo', 'italiana', 'forza', 'paese', 'essere', 'così', 'solo']
#
# Topic #422:
#
# ['toscana', 'nuovi', 'casi', 'decessi', 'guarigioni', 'decesso', 'coronavirus', 'nessun', 'ricoveri', 'aggiornamento']
#
# Topic #9:
#
# ['sale', 'totale', 'paese', 'decessi', 'morti', 'mondo', 'nuovi', 'coronavirus', 'iran', 'ecuador']
#
# Topic #396:
#
# ['vaccino', 'studio', 'coronavirus', 'vaccini', 'farmaco', 'arcuri', 'anno', 'speranza', 'entro', 'anti']
#
# Topic #216:
#
# ['india', 'casi', 'hopkins', 'mondo', 'johns', 'milioni', 'record', 'contagi', 'university', 'oltre']
#
# Topic #312:
#
# ['2020', '2021', 'anno', 'covid19', 'marzo', '2019', '2022', 'febbraio', 'stato', 'solo']
#
# Topic #193:
#
# ['voli', 'aereo', 'aerei', 'ryanair', 'volo', 'coronavirus', 'passeggeri', 'aeroporto', 'airlines', 'italia']
#
# Topic #345:
#
# ['fascisti', 'fascista', 'comunista', 'fascismo', 'comunisti', 'nazisti', 'comunismo', 'nazi', 'nazismo', 'nazista']
#
# Topic #277:
#
# ['francia', 'parigi', 'macron', 'coronavirus', 'francese', 'francesi', 'lockdown', 'coprifuoco', 'allerta', 'contagi']
#
# Topic #174:
#
# ['tweet', 'twitter', 'scritto', 'commenti', 'leggere', 'fa', 'solo', 'account', 'quando', 'profilo']
#
# Topic #354:
#
# ['giornalisti', 'giornalismo', 'giornalista', 'giornali', 'giornale', 'fake', 'media', 'stampa', 'news', 'notizie']
#
# Topic #234:
#
# ['palermo', 'turista', 'coronavirus', 'caso', 'bergamasca', 'bergamo', 'sicilia', 'orlando', 'positiva', 'cervello']
#
# Topic #449:
#
# ['covid19', 'coronavirusitalia', 'covid19italia', 'covid_19', 'coronavirus', 'covid2019', 'covid19italy', 'sarscov2', 'covid2019italia', 'covid__19']
#
# Topic #134:
#
# ['bolsonaro', 'brasile', 'presidente', 'positivo', 'trump', 'jair', 'brasiliano', 'coronavirus', 'covid19', 'morti']
#
# Topic #267:
#
# ['bambini', 'coronavirus', 'pediatri', 'pediatra', 'bimbi', 'figli', 'spiegato', 'genitori', 'figlio', 'adulti']
#
# Topic #282:
#
# ['puntata', 'diretta', '00', 'radio', 'ore', 'oggi', 'podcast', 'onda', 'domani', 'radio1rai']
#
# Topic #457:
#
# ['morti', 'positivi', 'bollettino', 'italia', 'positività', 'tasso', 'casi', 'nuovi', 'oggi', 'coronavirus']
#
# Topic #223:
#
# ['anziani', 'giovani', 'pensione', 'pensionati', 'indispensabili', 'vecchi', 'persone', 'pensioni', 'produttivo', 'sforzo']
#
# Topic #258:
#
# ['arancione', 'zona', 'gialla', 'arancioni', 'giallo', 'rossa', 'covid19', 'rosso', 'lombardia', 'gialle']
#
# Topic #239:
#
# ['napoli', 'coronavirus', 'cotugno', 'ospedale', 'sindaco', 'firenze', 'napoletani', 'lungomare', 'sputa', 'quarantena']
#
# Topic #162:
#
# ['gt', 'basilicata', 'coronavirus', 'matera', 'leggi', 'positivi', 'salernitanoleggi', 'emergenza', 'salernitano', 'ultim']
#
# Topic #421:
#
# ['morti', 'morto', 'muore', 'coronavirus', 'morte', 'morire', 'solo', 'muoiono', 'morta', 'robertoburioni']
#
# Topic #424:
#
# ['euro', 'milioni', 'miliardi', 'dona', 'coronavirus', 'mila', 'emergenza', 'lavoro', 'mln', 'imprese']
#
# Topic #276:
#
# ['francia', 'francesi', 'francese', 'macron', 'parigi', 'covid19', 'lockdown', 'france', 'coprifuoco', 'emmanuel']
#
# Topic #164:
#
# ['2020', '19', 'guglionesi', '2021', 'aggiornamento', 'covid', 'pietroburgo', 'comune', 'emergenza', 'san']
#
# Topic #172:
#
# ['coronavirus', 'salvini', 'matteosalvinimi', 'fontana', 'governo', 'conte', 'stato', 'invasione', 'vaccino', 'dopo']
#
# Topic #229:
#
# ['mani', 'mascherine', 'mascherina', 'lavarsi', 'coronavirus', 'guanti', 'maschera', 'maschere', 'lavare', 'indossare']
#
# Topic #74:
#
# ['iran', 'iraniano', 'morti', 'coronavirus', 'iraniani', 'iraniana', 'vittime', 'qom', 'sanzioni', 'viceministro']
#
# Topic #330:
#
# ['pandemia', '19', 'covid', 'covid19', 'epidemia', 'impatto', 'durante', 'effetti', 'quando', 'solo']
#
# Topic #77:
#
# ['gates', 'bill', 'vaccino', 'musk', 'tesla', 'billgates', 'elon', 'profezia', 'coronavirus', 'pandemia']
#
# Topic #111:
#
# ['terrorismo', 'mediatico', 'terroristi', 'psicologico', 'covid19', 'basta', 'terrorista', 'bomba', 'media', 'solo']
#
# Topic #114:
#
# ['apple', 'iphone', 'google', 'ios', 'app', 'store', 'tracciamento', 'coronavirus', '19', 'covid']
#
# Topic #244:
#
# ['treni', 'treno', 'milano', 'stazione', 'coronavirus', 'trenitalia', 'fuga', 'passeggeri', 'bus', 'ferrovie']
#
# Topic #262:
#
# ['regioni', 'regione', 'governo', 'presidenti', 'regionali', 'regionale', 'responsabilità', 'presidente', 'tutte', 'solo']
#
# Topic #147:
#
# ['corea', 'sud', 'kim', 'nord', 'jong', 'casi', 'seul', 'coronavirus', 'korea', 'contagi']
#
# Topic #80:
#
# ['playhitmusic', 'coronavirus', 'bollettino', 'oggi', 'civile', 'dati', 'protezione', 'italia', 'lombardia', 'agosto']
#
# Topic #418:
#
# ['virus', 'morto', 'clinicamente', 'solo', 'meno', 'fatto', 'virologi', 'dire', 'cosa', 'esiste']
#
# Topic #377:
#
# ['ronaldo', 'cristiano', 'messi', 'positivo', 'juventus', 'maradona', 'cr7', 'portoghese', 'cristianoronaldo', 'juve']
#
# Topic #136:
#
# ['mappa', 'italia', 'contagio', 'reale', 'contagi', 'coronavirus', 'tempo', 'aggiornata', 'interattiva', 'mappe']
#
# Topic #350:
#
# ['salvini', 'meloni', 'lega', 'quando', 'matteosalvinimi', 'renzi', 'solo', 'matteo', 'governo', 'cosa']
#
# Topic #325:
#
# ['conte', 'casalino', 'linkiesta', 'fa', 'cosa', 'pd', 'fatto', 'stato', 'draghi', 'fregato']
#
# Topic #0:
#
# ['piacere', 'pezzo', 'interessa', 'grazie', 'follow', 'prego', 'ricambiato', 'pezzi', 'back', 'blog']
#
# Topic #442:
#
# ['liguria', 'positivi', 'nuovi', 'savonese', 'coronavirus', 'casi', 'provincia', 'imperia', 'oggi', '24']
#
# Topic #259:
#
# ['arancione', 'zona', 'regioni', 'arancioni', 'rossa', 'coronavirus', 'gialla', 'sicilia', 'rosse', 'toscana']
#
# Topic #460:
#
# ['coronavirus', 'cosa', 'matteosalvinimi', 'entra', 'oppure', 'sai', 'skytg24', 'forse', 'ah', 'ce']
#
# Topic #437:
#
# ['bene', 'sempre', 'va', 'meglio', 'ora', 'così', 'solo', 'proprio', 'fine', 'ce']
#
# Topic #65:
#
# ['età', 'media', 'anni', 'toscana', 'nuovi', 'decessi', 'casi', '44', '45', '43']
#
# Topic #375:
#
# ['votare', 'votato', 'voto', 'elezioni', 'elettorale', 'voti', 'vota', 'votano', 'campagna', 'elettori']
#
# Topic #157:
#
# ['sarscov2', 'fakenews', 'stato', 'detto', 'creato', 'ideato', 'sviluppato', 'farci', 'complotto', 'bufala']
#
# Topic #192:
#
# ['voli', 'aerei', 'aereo', 'volo', 'alitalia', 'passeggeri', 'compagnie', 'easyjet', 'covid19', 'aeree']
#
# Topic #409:
#
# ['que', 'el', 'pero', 'esto', 'tangina', 'es', 'mano', 'de', 'im', 'meo']
#
# Topic #404:
#
# ['sindaco', 'coronavirus', 'polizia', 'torino', 'controlli', 'strade', 'carabinieri', 'bari', 'via', 'comune']
#
# Topic #383:
#
# ['governo', 'politica', 'coronavirus', 'matteosalvinimi', 'politici', 'solo', 'governi', 'stato', 'fatto', 'politico']
#
# Topic #253:
#
# ['smart', 'working', 'smartworking', 'digitale', 'coronavirus', 'google', 'aziende', 'lavoro', 'emergenza', 'dipendenti']
#
# Topic #326:
#
# ['smartworking', 'smart', 'working', 'lavoro', 'covid19', 'emergenza', 'lavorare', 'dipendenti', 'aziende', 'lavoratori']
#
# Topic #448:
#
# ['coronavirus', 'coronavirusitalia', 'bene', 'amuchina', 'speriamo', 'coronavirusitalla', 'buon', 'leggere', 'così', 'cazzo']
#
# Topic #382:
#
# ['italia', 'italiani', 'coronavirus', 'matteosalvinimi', 'paese', 'italiano', 'problema', 'fatto', 'arrivato', 'solo']
#
# Topic #113:
#
# ['coronaviruscases', 'contagiati', 'notizie', 'ultime', 'oggi', 'morti', 'casi', 'coronavirus', 'san', 'morto']
#
# Topic #320:
#
# ['regione', 'regioni', 'regionale', 'musumeci', 'coronavirus', 'sicilia', 'ordinanza', 'regionali', 'misure', 'emergenza']
#
# Topic #159:
#
# ['fakenews', 'stato', 'detto', 'creato', 'complotto', 'farci', 'ideato', 'bufala', 'sviluppato', 'video']
#
# Topic #315:
#
# ['ristoranti', 'bar', 'chiusi', 'coronavirus', 'parrucchieri', '18', 'negozi', 'pub', 'ristorante', 'palestre']
#
# Topic #359:
#
# ['lombardia', 'positivi', 'nuovi', 'varesotto', 'decessi', 'milano', 'coronavirus', 'casi', 'bergamo', 'tamponi']
#
# Topic #53:
#
# ['pizza', 'pizzeria', 'video', 'francese', 'pizze', 'canal', 'francia', 'coronavirus', 'mandolino', 'hut']
#
# Topic #245:
#
# ['positiva', 'bimbo', 'bimba', 'anni', 'bambino', 'positivo', 'bambina', 'donna', 'partorisce', 'incinta']
#
# Topic #293:
#
# ['2020', 'bollettino', 'lopinionista', 'italia', 'emergenza', 'coronavirus', 'dati', '2021', 'giorno', 'aggiornamento']
#
# Topic #150:
#
# ['giappone', 'tokyo', 'giapponese', 'emergenza', 'stato', 'giapponesi', 'abe', 'suicidi', 'coronavirus', 'borsa']
#
# Topic #269:
#
# ['giovani', 'coronavirus', 'allarme', 'adolescenti', 'appello', 'draghi', 'attenzione', 'oms', 'movida', 'contagiati']
#
# Topic #211:
#
# ['tennis', 'djokovic', 'positivo', 'novak', 'torneo', 'tennista', 'adria', 'dimitrov', 'fognini', 'tour']
#
# Topic #200:
#
# ['m5s', 'pd', 'coronavirus', 'senatori', 'lega', 'salvini', 'emergenza', 'aula', 'senato', 'attacca']
#
# Topic #263:
#
# ['sars', 'cov', 'sarscov2', 'virus', 'cov2', 'nuovo', 'studio', 'variante', 'coronavirus', 'infezione']
#
# Topic #426:
#
# ['jsjsjs', 'jsjsjsjs', 'jsjsjsjsjs', 'que', 'jsjs', 'jsjsjsj', 'jajsjsjs', 'el', 'es', 'lpm']
#
# Topic #143:
#
# ['diamond', 'princess', 'nave', 'passeggeri', 'italiani', 'italiano', 'bordo', 'coronavirus', 'crociera', 'volo']
#
# Topic #332:
#
# ['vaccino', 'sperimentazione', 'test', 'uomo', 'primi', 'spallanzani', 'via', 'italiano', 'coronavirus', 'volontari']
#
# Topic #256:
#
# ['milano', 'milanononsiferma', 'milanesi', 'navigli', 'covid19', 'sala', 'città', 'lombardia', 'gente', 'lockdown']
#
# Topic #5:
#
# ['ncov', 'polmonite', '2019', 'informazioni', 'aggiornamenti', 'ultimo', 'epidemia', '20', 'aggiornamento', '07']
#
# Topic #348:
#
# ['notizia', 'notizie', 'buona', 'bella', 'buone', 'news', 'belle', 'ottima', 'noticia', 'finalmente']
#
# Topic #358:
#
# ['mesi', 'estate', 'marzo', 'mese', 'dopo', 'due', 'anno', 'giugno', 'settembre', 'giorni']
#
# Topic #432:
#
# ['ahahah', 'ahahahah', 'hahahaha', 'hahaha', 'hahahahaha', 'hahahahaahh', 'hahahahah', 'puta', 'ahahahahahahahahaha', 'haha']
#
# Topic #170:
#
# ['video', 'coronavirus', 'cosa', 'ondata', 'scuola', 'meteo', 'contagi', 'nuovo', 'seconda', 'regioni']
#
# Topic #393:
#
# ['stati', '24', 'morti', 'ultime', 'ore', 'casi', 'nuovi', 'italia', 'covid19', 'guariti']
#
# Topic #24:
#
# ['2020positivi', '11', '1guariti', '12', 'positividecessi', '10', 'record', 'malvezzi', '2guariti', '0guariti']
#
# Topic #102:
#
# ['5g', 'antenne', 'causa', 'correlazione', 'coronavirus', 'rete', 'covid19', 'antenna', 'scie', 'complottismo']
#
# Topic #60:
#
# ['grecia', 'greci', 'croazia', 'spagna', 'italia', 'malta', 'coronavirus', 'turisti', 'atene', 'greca']
#
# Topic #233:
#
# ['tamponi', 'positivi', 'nuovi', 'ieri', 'casi', 'covid19dati', 'ricoverati', 'effettuati', 'toscana', 'oggi']
#
# Topic #48:
#
# ['canada', 'chinetown', 'cina', 'topwomen', 'dimagazine', 'marcellacaradonna', 'valeriana', 'mariani', 'sandroferrari', 'magazine']
#
# Topic #21:
#
# ['compilare', 'anonimo', 'questionario', 'condividere', 'scientifica', 'prego', 'sostenibilità', 'ricerca', 'teresabellanova', 'questionar']
#
# Topic #270:
#
# ['spagna', 'madrid', 'sanchez', 'coronavirus', 'spagnolo', 'restrizioni', 'spagnoli', 'stato', 'esercito', 'spagnola']
#
# Topic #62:
#
# ['articolo', 'nuovo', 'messina', 'stato', 'pubblicato', 'sicilia', 'tempo', 'calabria', 'tamponi', 'nuovi']
#
# Topic #445:
#
# ['coronavirus', 'governo', 'coronavirusitalia', 'casa', 'finanza', 'rieticna', 'pillole', 'emergenza', 'basta', 'leggi']
#
# Topic #228:
#
# ['migranti', 'positivi', 'sbarcati', 'roccella', '28', 'pozzallo', 'immigrati', 'amantea', 'lampedusa', 'jonica']
#
# Topic #413:
#
# ['bravo', 'vergogna', 'gimmie', 'dale', 'aro', 'basta', 'sceemo', 'vaccine', 'illegalita', 'vaffanculo']
#
# Topic #104:
#
# ['razzismo', 'razzisti', 'razzista', 'coronavirus', 'paura', 'virus', 'solo', 'sardine', 'problema', 'odio']
#
# Topic #311:
#
# ['emergenza', 'stato', 'finita', 'gestire', 'quando', 'soccorso', 'paese', 'situazione', 'solo', 'cosa']
#
# Topic #327:
#
# ['digitale', 'digitalizzazione', 'digital', 'digitali', '19', 'covid', 'covid19', 'innovazione', 'trasformazione', 'post']
#
# Topic #198:
#
# ['lazio', 'covid19', 'zingaretti', 'regione', 'tar', 'lotito', 'immobile', 'inzaghi', 'zona', 'oggi']
#
# Topic #403:
#
# ['fase', 'fase2', 'due', 'fase1', 'covid19', 'fase3', 'pronti', 'conte', 'maggio', 'prima']
#
# Topic #191:
#
# ['nave', 'crociera', 'civitavecchia', 'bordo', 'costa', 'navi', 'passeggeri', 'smeralda', 'sospetti', 'due']
#
# Topic #339:
#
# ['farmaci', 'farmaco', 'farmaceutiche', 'dose', 'case', 'pfizer', 'farmacia', 'farmacisti', 'pharma', 'farmaceutica']
#
# Topic #236:
#
# ['laboratorio', 'wuhan', 'creato', 'pompeo', 'prove', 'nato', 'virus', 'usa', 'yan', 'origine']
#
# Topic #441:
#
# ['marche', 'ancona', 'provincia', 'positivi', 'pesaro', 'nuovi', 'gores', 'tamponi', 'urbino', 'ascoli']
#
# Topic #323:
#
# ['abruzzo', 'notizieabruzzo', 'giorno', 'dati', '2021', 'aggiornamenti', 'aggiornamento', '2020', 'emergenza', 'basilicata']
#
# Topic #178:
#
# ['plasma', 'iperimmune', 'cura', 'terapia', '19', 'covid', 'guariti', 'pazienti', 'covid19', 'sperimentazione']
#
# Topic #152:
#
# ['fakenews', 'stato', 'detto', 'covid19', 'farci', 'bufala', 'complotto', 'creato', 'lobby', 'ideato']
#
# Topic #455:
#
# ['liguria', 'nuovi', 'casi', 'contagi', 'decessi', 'coronavirus', '24', 'ore', 'imperia', 'ultime']
#
# Topic #372:
#
# ['sannio', 'bollettino', 'aggiornati', 'aggiornamento', 'dati', 'oggi', 'updayit', 'coronavirus', 'aprile', 'gennaio']
#
# Topic #387:
#
# ['oh', 'nooooo', 'nooo', 'noooo', 'noooooo', 'nono', 'nh', 'nooooooo', 'tata', 'nononono']
#
# Topic #2:
#
# ['dw', 'inquietante', 'verità', 'forse', 'parlato', 'parlat', 'parla', 'coronavirus', 'qu', 'genovaonline']
#
# Topic #454:
#
# ['decessi', 'nuovi', 'casi', 'bollettino', 'nazionale', 'coronavirus', 'contagi', 'guariti', 'fvg', 'tamponi']
#
# Topic #199:
#
# ['aosta', 'valle', 'positivi', 'nuovi', 'casi', 'coronavirus', 'guariti', 'nessun', 'decesso', 'decessi']
#
# Topic #390:
#
# ['napoli', 'napoletani', 'covid19', 'demagistris', 'città', 'sempre', 'fatto', 'solo', 'deluca', 'italia']
#
# Topic #319:
#
# ['rossa', 'zona', 'rosse', 'zone', 'coronavirus', 'mondragone', 'musumeci', 'sicilia', 'ordinanza', 'mini']
#
# Topic #127:
#
# ['ciclismo', 'bicicletta', 'ciclista', 'bici', 'ciclisti', 'biciclette', 'giro', 'bike', 'tour', 'ciclabili']
#
# Topic #363:
#
# ['supermercati', 'assalto', 'aperto', 'obbligo', 'presi', 'mascherina', 'mascherine', 'code', 'coronavirus', 'scaffali']
#
# Topic #412:
#
# ['hahahaahah', 'que', 'ahahah', 'hahaahhaha', 'hahahahaahaha', 'hahahaah', 'congrats', 'hahahahahah', 'quoi', 'hahahahah']
#
# Topic #222:
#
# ['bambini', 'figli', 'genitori', 'bambino', 'figlio', 'figlia', 'papà', 'padre', 'anni', 'asilo']
#
# Topic #324:
#
# ['nba', 'giocatori', 'nbatwitter', 'lakers', 'gobert', 'basket', 'bolla', 'positivo', 'lebron', 'westbrook']
#
# Topic #220:
#
# ['plasma', 'cura', 'iperimmune', 'terapia', 'guariti', 'sperimentazione', 'coronavirus', 'funziona', 'pazienti', 'donatori']
#
# Topic #385:
#
# ['twitter', 'tweet', 'coronavirus', 'leggo', 'hashtag', 'apro', 'ogni', 'solo', 'account', 'quando']
#
# Topic #344:
#
# ['democrazia', 'democratici', 'democratico', 'democratica', 'libertà', 'democrazie', 'covid19', 'dittatura', 'stato', 'stati']
#
# Topic #380:
#
# ['ministro', 'ministra', 'robersperanza', 'ministri', 'speranza', 'interni', 'ministero', 'esteri', 'interno', 'bellanova']
#
# Topic #266:
#
# ['polmonite', 'polmoni', 'fumo', 'fumatori', 'sigarette', 'fumare', 'sintomi', 'interstiziale', 'solo', 'polmonari']
#
# Topic #433:
#
# ['speriamo', 'speranza', 'spero', 'presto', 'bene', 'aspettando', 'vada', 'aspetta', 'riprenda', 'speranze']
#
# Topic #291:
#
# ['civile', 'protezione', 'bollettino', 'dati', 'sardegna', 'oggi', 'giugno', 'coronavirus', 'settembre', 'italia']
#
# Topic #181:
#
# ['anziani', 'anziane', 'vecchi', 'persone', 'patologie', 'coronavirus', 'solo', 'colpisce', 'morire', 'muoiono']
#
# Topic #20:
#
# ['cambiamentoclimatico', 'incendi', 'grandi', 'domani', 'ieri', 'solo', 'oggi', 'coronavirus', 'ricercapubblica', 'climate']
#
# Topic #314:
#
# ['numeri', 'percentuale', 'numero', 'dire', 'cosa', 'solo', 'letalità', '80', 'sempre', 'cazzo']
#
# Topic #26:
#
# ['andamento', 'aggi', 'informazioni', 'covid19italia', 'coronavirusitalia', 'italia', 'casi', 'covid19', 'mensile', '10']
#
# Topic #378:
#
# ['politica', 'politici', 'politico', 'classe', 'politiche', 'quando', 'fa', 'parte', 'parole', 'livello']
#
# Topic #22:
#
# ['tendenze', 'entrato', 'posizione', 'popolari', 'hashtag', 'italia', 'evidenza', 'top', '01', '10']
#
# Topic #82:
#
# ['latest', 'the', 'thanks', 'to', 'daily', 'covid19', 'twittdestra', 'magliano', 'osigs', 'giovagnoni']
#
# Topic #283:
#
# ['podcast', 'spreaker', 'nuovo', 'edizione', 'informazione', 'coronavirus', '2020', 'radioabm', 'ansa', 'adelaide']
#
# Topic #254:
#
# ['sud', 'nord', 'meridionali', 'inferiori', 'meridionale', 'feltri', 'lega', 'regioni', 'ignorare', 'vfeltri']
#
# Topic #149:
#
# ['olimpiadi', 'tokyo', 'giochi', 'tokyo2020', '2021', 'cio', 'olimpici', 'giappone', '2020', 'rischio']
#
# Topic #153:
#
# ['voli', 'cina', 'aereo', 'italia', 'pechino', 'traffico', 'coronavirus', 'blocco', 'aerei', 'volo']
#
# Topic #353:
#
# ['sempre', 'ditto', 'fato', 'torniamoliberi', 'hrspenyelamatislam', 'direitacombolsonaro', 'fechadoscombolsonaro', 'brasilcombolsonaro', 'fechadocombolsonaro', 'zangrillo']
#
# Topic #189:
#
# ['vittime', 'memoria', 'giornata', 'nazionale', '18marzo', 'giornatanazionale', 'covid19', 'covid', 'ricordo', '18']
#
# Topic #331:
#
# ['positivo', 'negativo', 'positivi', 'negativi', 'tampone', 'positiva', 'positive', 'essere', 'debolmente', 'stay']
#
# Topic #351:
#
# ['forze', 'polizia', 'ordine', 'proteste', 'protestare', 'carabinieri', 'protesta', 'manifestanti', 'poliziotti', 'manifestazioni']
#
# Topic #235:
#
# ['musei', 'museo', 'biblioteche', 'cultura', 'chiusi', 'riaprono', 'gratis', 'coronavirus', 'mostre', 'firenze']
#
# Topic #190:
#
# ['abruzzo', 'pescara', 'laquila', 'chieti', 'teramo', 'coronavirusitalia', 'pandemia', 'bollettinoabruzzo', 'domenica', 'covid']
#
# Topic #179:
#
# ['whatsapp', 'audio', 'fake', 'gruppi', 'messaggio', 'messaggi', 'news', 'falsi', 'vocali', 'coronavirus']
#
# Topic #430:
#
# ['detto', 'dice', 'dire', 'parole', 'dicono', 'cosa', 'ce', 'dirlo', 'mai', 've']
#
# Topic #204:
#
# ['svizzera', 'situazione', 'coronavirus', 'contagi', 'italia', 'swisscovid', 'protezionecivile', 'zurigo', 'swiss', 'federale']
#
# Topic #401:
#
# ['dpcm', 'nuovo', 'conte', 'misure', 'firma', 'vigore', 'cosa', 'coronavirus', 'nuove', 'firmato']
#
# Topic #160:
#
# ['verde', 'numero', '800', 'attivo', '833', 'psicologico', 'regione', 'verdi', 'informazioni', 'chiamate']
#
# Topic #32:
#
# ['odierni', 'live', 'numeri', 'bollettino', 'regione', 'covid_19', 'covid19italia', 'covid19', 'coronavirus', 'covid__19']
#
# Topic #278:
#
# ['francia', 'casi', 'oltre', '24', 'ore', 'record', 'contagi', 'nuovi', 'ultime', 'spagna']
#
# Topic #436:
#
# ['test', 'negativo', 'negativi', 'coronavirus', 'paziente', 'positivo', 'spallanzani', 'sospetto', 'donna', 'niccolò']
#
# Topic #463:
#
# ['positivo', 'scorta', 'positiva', 'agente', 'salvini', 'coronavirus', 'poliziotto', 'bene', 'deputato', 'presidente']
#
# Topic #394:
#
# ['vaccino', 'vaccini', 'coronavirus', 'esiste', 'novax', 'vaccinarsi', 'vax', 'antinfluenzale', 'alessiamorani', 'robertoburioni']
#
# Topic #138:
#
# ['arcuri', 'primule', 'commissario', 'mascherine', 'incapace', 'stato', 'solo', 'fallisce', 'banchi', 'divano']
#
# Topic #346:
#
# ['dati', 'leggere', 'cartabellotta', 'ondatait', 'grafici', 'ruffino_lorenzo', 'grazie', 'giuseppeconteit', 'grafico', 'antonio_caramia']
#
# Topic #34:
#
# ['aggiornamento', '24', 'ultime', 'ore', 'decessi', 'nuovi', 'asintomatici', 'casi', 'ottobre', 'novembre']
#
# Topic #17:
#
# ['blog', 'contributo', 'interessa', 'ricambia', 'follow', 'nuovo', 'va', 'buona', 'pomeriggio', 'buonanotte']
#
# Topic #367:
#
# ['dire', 'cose', 'detto', 'sempre', 'so', 'matteosalvinimi', 'sa', 'contrario', 'già', 'marattin']
#
# Topic #122:
#
# ['pos', 'ieri', '11diagnosi', '12diagnosi', 'ottobrediagnosi', '1ricoveri', '2ricoveri', '1diagnosi', 'valdaosta', '11']
#
# Topic #298:
#
# ['wuhan', 'poi', 'km', 'stato', 'matteosalvinimi', 'città', 'viaggio', 'andata', 'bene', 'ora']
#
# Topic #264:
#
# ['natale', 'coronavirus', 'capodanno', 'conte', 'terza', 'ondata', 'baci', 'abbracci', 'feste', 'cts']
#
# Topic #246:
#
# ['canta', 'musica', 'festival', 'canzone', 'sangiorgi', 'repubblica', 'coronavirus', 'via', 'video', 'giuliano']
#
# Topic #360:
#
# ['articolo', 'interessante', 'articoli', 'letto', 'leggere', 'trovato', 'legga', 'quest', 'molto', 'grazie']
#
# Topic #395:
#
# ['turismo', 'imprese', 'famiglie', 'coronavirus', 'crisi', 'misure', 'sostegno', 'turistiche', 'settore', 'turistico']
#
# Topic #107:
#
# ['regina', 'elisabetta', 'principe', 'carlo', 'discorso', 'kate', 'william', 'filippo', 'ii', 'buckingham']
#
# Topic #338:
#
# ['idrossiclorochina', 'farmaco', '19', 'covid', 'trattamento', 'covid19', 'aifa', 'farmaci', 'uso', 'pazienti']
#
# Topic #386:
#
# ['ibrahimovic', 'milan', 'zlatan', 'positivo', 'ibra', 'covid19', 'guarito', 'risultato', 'ibra_official', 'duarte']
#
# Topic #119:
#
# ['guariti', 'bollettino', 'terapie', 'intensive', 'contagiati', 'morti', 'oggi', 'contagi', 'tamponi', '13']
#
# Topic #137:
#
# ['wuhan', 'ospedale', 'giorni', 'costruito', '10', 'timelapse', 'costruzione', 'morto', 'completato', 'direttore']
#
# Topic #208:
#
# ['guerra', 'donne', 'guerre', 'uomini', 'combattendo', 'poveri', 'civile', 'vincere', 'solo', 'tempo']
#
# Topic #194:
#
# ['ospedale', 'medici', 'coronavirus', 'ospedali', 'infermieri', 'emergenza', 'personale', 'medico', 'sanitario', 'pronto']
#
# Topic #230:
#
# ['lombardia', 'dati', 'oggi', 'bollettino', 'coronavirus', 'diffusi', 'agosto', 'maggio', 'novembre', 'luglio']
#
# Topic #58:
#
# ['greco', 'torre', 'guarigioni', 'torredelgreco', 'casi', 'nuovi', 'cronaca', 'giovannipalomba', 'decesso', 'clicca']
#
# Topic #397:
#
# ['quando', 'può', 'cose', 'sempre', 'gente', 'ciò', 'solo', 'cosa', 'proprio', 'persone']
#
# Topic #182:
#
# ['autocertificazione', 'modulo', 'nuovo', 'spostamenti', 'cambia', 'modello', 'autodichiarazione', 'scaricare', 'coronavirus', 'pdf']
#
# Topic #301:
#
# ['lombarda', 'sanità', 'lombardia', 'lombardi', 'lombardo', 'eccellenza', 'sanitaria', 'sanitario', 'gestione', 'modello']
#
# Topic #188:
#
# ['vitamina', 'studio', 'carenza', 'ridurre', '19', 'covid', 'vitamin', 'rischio', 'torino', 'vitaminad']
#
# Topic #217:
#
# ['piangere', 'piangendo', 'lacrime', 'viene', 'piango', 'ridere', 'pianto', 'voglio', 'metto', 'so']
#
# Topic #238:
#
# ['corona', 'hate', 'go', 'coro', 'ciao', 'pro', 'data', 'waah', 'fights', 'fraud']
#
# Topic #115:
#
# ['newsicilia', 'coronavirus', 'italia', 'ultim', 'flash', 'ora', 'sicilia', 'dati', 'breaking', 'stelle']
#
# Topic #46:
#
# ['molise', 'molisenews24', 'giorno', 'dati', '2020', '2021', 'novembre', 'dicembre', 'ottobre', 'coronavirus']
#
# Topic #255:
#
# ['fontana', 'gallera', 'zaia', 'attilio', 'bertolaso', 'lombardia', 'colpa', 'fatto', 'salvini', 'dopo']
#
# Topic #440:
#
# ['toscana', 'positivi', 'nuovi', 'decessi', 'guarigioni', 'casi', 'coronavirus', 'guariti', 'dati', 'deceduti']
#
# Topic #388:
#
# ['positivi', 'basilicata', 'covid', '19', 'campania', 'nuovi', 'oggi', 'calabria', 'tamponi', 'covid19']
#
# Topic #249:
#
# ['abruzzo', 'casi', 'nuovi', 'campania', 'cronaca', 'ultimenotiziecalcionapolieaggiornamentih24', 'ore', '24', 'coronavirus', 'ultime']
#
# Topic #271:
#
# ['spagna', 'spagnola', 'spagnoli', 'spagnolo', 'ondata', 'seconda', 'governo', 'padrone', 'asino', 'riconosce']
#
# Topic #171:
#
# ['youtube', 'via', 'coronavirus', 'video', 'consigli', 'nonna', 'guarda', 'parere', 'cosa', 'liked']
#
# Topic #90:
#
# ['bolzano', 'trento', 'rieti', 'frosinone', 'viterbo', 'covid_19', 'latina', 'veneto', 'bilancio', 'covid19']
#
# Topic #399:
#
# ['fontana', 'coronavirus', 'conte', 'rifarei', 'attilio', 'sindaci', 'presidente', 'sapevatelo', 'critiche', 'lodi']
#
# Topic #12:
#
# ['radioradiotv', 'dicono', 'savona', 'spezia', 'imperia', 'genova', 'coronavirus', 'covid19', '091', '62']
#
# Topic #337:
#
# ['libertà', 'liberi', 'libero', 'liberta', 'quando', 'espressione', 'pensiero', 'essere', 'può', 'dire']
#
# Topic #285:
#
# ['mamma', 'madre', 'mama', 'miaaa', 'chinga', 'oh', 'padre', 'rusia', 'papà', 'mo']
#
# Topic #343:
#
# ['crisi', 'economia', 'economica', 'momenti', 'economista', 'economisti', 'essere', 'può', 'soprattutto', 'attuale']
#
# Topic #23:
#
# ['scuso', 'mandato', 'pezzo', 'interessa', 'già', 'buonanotte', 'serata', 'buona', 'follow', 'ricambia']
#
# Topic #286:
#
# ['2020', 'ministerosalute', 'bollettino', 'dati', 'oggi', '2021', 'emiliaromagna', 'aprile', 'coronavirus', 'bollettinomedico']
#
# Topic #242:
#
# ['austria', 'frontiere', 'confini', 'italia', 'kurz', 'croazia', 'coronavirus', 'francia', 'germania', 'slovenia']
#
# Topic #126:
#
# ['turchia', 'erdogan', 'turco', 'turchi', 'turca', 'turkmenistan', 'erdoğan', 'covid19', 'ankara', 'siria']
#
# Topic #419:
#
# ['virus', 'fa', 'barillaridav', 'virologi', 'fabrizioboratto', 'bruno72513183', 'solo', 'wuhan', 'diametro', 'cartabellotta']
#
# Topic #11:
#
# ['prot', 'agg', 'screenshot', 'tot', 'by', 'foto', 'civile', 'italiana', 'aumen', 'ieri']
#
# Topic #370:
#
# ['oggi', 'domani', 'giorno', 'giornata', 'ieri', 'giorni', 'buongiorno', 'meglio', 'ogni', 'infern']
#
# Topic #335:
#
# ['banche', 'banca', 'centrali', 'bankitalia', 'coronavirus', 'banksy', 'abi', 'bce', 'bancario', 'crisi']
#
# Topic #19:
#
# ['dreamlab', 'supportato', 'youtrend', 'completato', 'elaborato', 'calcoli', 'gravità', 'secondi', 'progetto', 'indice']
#
# Topic #371:
#
# ['sicilia', 'campania', 'bollettino', 'province', 'maggio', 'aggiornati', 'oggi', 'regione', 'aggiornamento', 'dati']
#
# Topic #1:
#
# ['pomeriggio', 'pezzo', 'interessa', 'buon', 'buona', 'quieto62', 'settimana', 'weekend', 'milkoscaglione', 'michelarabino']
#
# Topic #142:
#
# ['amore', 'tempi', 'tempo', 'coronavirus', 'colera', 'tvboy', 'amuchina', 'sesso', 'romanzo', 'love']
#
# Topic #265:
#
# ['facebook', 'fake', 'news', 'coronavirus', 'social', 'rimuoverà', 'bufale', 'post', 'false', 'milioni']
#
# Topic #374:
#
# ['italia', 'italiani', 'giuseppeconteit', 'italiano', 'matteosalvinimi', 'resto', 'paese', 'quirinale', 'purtroppo', 'cosa']
#
# Topic #462:
#
# ['tamponi', 'positivi', 'nuovi', 'guariti', 'oltre', 'aggiornamento', 'effettuati', 'asintomatici', 'attivi', 'decessi']
#
# Topic #321:
#
# ['sondaggio', 'sondaggi', 'secondo', 'intervistati', 'italiani', 'risultati', 'ipsos', 'conte', 'elettorali', 'risultato']
#
# Topic #218:
#
# ['martino', 'san', 'genova', 'ricoverati', 'ospedale', 'coronavirus', 'policlinico', 'pazienti', 'infettive', 'decessi']
#
# Topic #318:
#
# ['liguria', 'toti', 'coronavirus', 'regione', 'caso', 'genova', 'ordinanza', 'dati', 'rt', 'valutiamo']
#
# Topic #366:
#
# ['magistratura', 'avvocato', 'indaghi', 'antenne', 'magistrato', 'giudice', 'correlazione', 'magistrati', 'giustizia', 'spero']
#
# Topic #158:
#
# ['lobby', 'fakenews', 'gay', 'lgbt', 'lgbtqi', 'stato', 'lgbti', 'covid19', 'detto', 'lgbtq']
#
# Topic #186:
#
# ['firenze', 'florida', 'covid19', 'nardella', 'floris', 'darionardella', 'sindaco', 'toscana', 'florence', 'comunefi']
#
# Topic #362:
#
# ['agenzia_ansa', 'corriere', 'rainews', 'adnkronos', 'skytg24', 'tg2rai', 'ilmessaggeroit', 'mediasettgcom24', 'lastampa', 'unomattina']
#
# Topic #287:
#
# ['2020', 'anno', '2021', 'coronavirus', '2019', 'vaffanculo', 'ricordato', 'virus', 'già', 'pandemia']
#
# Topic #6:
#
# ['buonanotte', 'pezzo', 'interessa', 'bigfootlouis', '_diana87', 'teglantide', 'portamiiviadate', 'lxilsi', 'ester_mercuri', 'anitafiaschetti']
#
# Topic #398:
#
# ['positivo', 'coronavirus', 'positiva', 'positivi', 'lato', 'positività', 'cosa', 'unica', 'essere', 'positive']
#
# Topic #54:
#
# ['voce', 'news', 'flash', 'diario', 'bordo', 'bari', '2020', 'vignetta', 'auguri', 'arresti']
#
# Topic #140:
#
# ['madonna', 'gaga', 'lady', 'contagiata', 'fan', 'coronavirus', 'instagram', 'video', 'cortellesi', 'padreterno']
#
# Topic #85:
#
# ['rispetto', 'calabria', 'ieri', 'regione', 'bollettino', '2021', 'coronavirus', 'gennaio', 'novembre', 'ottobre']
#
# Topic #56:
#
# ['asl', 'uscite', 'sorveglianza', 'domiciliare', 'persone', 'registrano', 'positivi', 'nuovi', 'roma', 'casi']
#
# Topic #209:
#
# ['sud', 'nord', 'coronavirus', 'meridionali', 'governatori', 'regioni', 'settentrionali', 'fatto', 'meridionale', 'terroni']
#
# Topic #307:
#
# ['saronno', 'busto', 'limbiate', 'varese', 'tradate', 'gallarate', 'cesano', 'caronno', 'contagi', 'groane']
#
# Topic #13:
#
# ['magazine', 'impresa', 'donna', 'topwomen', 'cina', 'marcellacaradonna', 'valeriana', 'mariani', 'sandroferrari', 'giugno']
#
# Topic #197:
#
# ['lazio', 'salutelazio', 'regione', 'bollettino', 'coronavirus', 'odierno', 'regionelazio', 'coprifuoco', 'coronavirusitalia', 'ordinanza']
#
# Topic #52:
#
# ['spallanzani', 'bollettino', 'coronavirus', 'finora', 'dimessi', 'ricoverati', '129', '89', '79', '1781']
#
# Topic #44:
#
# ['vs', 'caltanissetta', 'agrigento', 'scorsa', 'forlì', 'siracusa', 'dati', 'lunedì', 'ferrara', 'cesena']
#
# Topic #96:
#
# ['24', 'ultime', 'campania', 'ore', 'guariti', 'regione', 'positivi', 'tamponi', 'morto', 'nessun']
#
# Topic #284:
#
# ['podcast', 'spreaker', 'nuovo', 'covid19', 'mezzora', 'episodio', 'puntata', 'goodmusic', 'joerock', '2020']
#
# Topic #59:
#
# ['grecia', 'malta', 'croazia', 'spagna', 'rientra', 'tamponi', 'tampone', 'obbligo', 'quarantena', 'rientri']
#
# Topic #205:
#
# ['svizzera', 'svizzeri', 'belgio', 'italia', 'svizzero', 'sceglie', 'cantone', 'può', 'federale', 'parte']
#
# Topic #333:
#
# ['banche', 'banca', 'bce', 'centrali', 'amore', 'liquidità', 'imprese', 'bankitalia', 'atto', 'miliardi']
#
# Topic #341:
#
# ['grazie', 'merci', 'cazzo', 'dio', 'mille', 'sempre', 'grazieeee', 'graziella', 'bravi', 'thank']
#
# Topic #184:
#
# ['terrorismo', '2020coronavirus', 'guerra', 'covid_19', 'coronavirusitalia', 'covidiots', 'terroristi', 'mediatico', 'bollettino', 'covid19']
#
# Topic #309:
#
# ['stampa', 'conferenza', 'diretta', 'conferenze', 'borrelli', 'conte', 'coronavirus', 'protezione', 'arcuri', 'civile']
#
# Topic #429:
#
# ['accordo', 'concordo', 'ragione', 'pienamente', 'capito', 'perfettamente', 'discordo', 'ditemi', 'condivido', 'completamente']
#
# Topic #57:
#
# ['odierni', 'numeri', 'bollettino', 'lombardia', 'covid19', 'veneto', 'campania', 'coronavirus', 'covid_19', 'calenzano']
#
# Topic #4:
#
# ['follow', 'ricambia', 'pezzo', 'interessa', 'va', 'pomeriggio', 'buon', 'buona', 'giornata', 'ricambi']
#
# Topic #202:
#
# ['ultime', '24', 'ore', 'morti', 'italia', 'nuovi', 'casi', 'guariti', 'coronavirus', '10']
#
# Topic #73:
#
# ['totale', 'contagio', 'confermati', 'confermato', 'nuovi', 'casi', 'southkorea', 'pazienti', 'caso', 'nuovo']
#
# Topic #121:
#
# ['positivi', '16', 'dati', 'lombardia', 'reglombardia', '17', 'coronavirus', '0totale', '12', '0guariti']
#
# Topic #177:
#
# ['puglia', 'test', 'raccontiamolapuglia', 'aggiornamento', 'infezione', 'registrati', 'incremento', 'stati', 'positivi', 'casi']
#
# Topic #7:
#
# ['serata', 'interessa', 'pezzo', 'buona', 'banscollector', 'mrsbolkonskaja', 'nmrpim', 'bwforever73', 'arielale78', 'enricabanti']
#
# Topic #417:
#
# ['ospedale', 'ospedali', 'coronavirus', 'asl', 'campo', 'medici', 'emergenza', 'triage', 'reparto', 'hospital']
#
# Topic #128:
#
# ['modena', 'rivolta', 'carceri', 'detenuti', 'carcere', 'morti', 'sequestrati', 'agenti', 'coronavirus', 'rivolte']
#
# Topic #203:
#
# ['regionelombardia', 'bollettino', 'dati', 'oggi', '2020', '2021', 'regionecampania', 'coronavirus', 'novembre', 'regione']
#
# Topic #376:
#
# ['politica', 'politici', 'politico', 'molti', 'politicaperjedi', 'politiche', 'matteorenzi', 'cartabellotta', 'quando', 'invece']
#
# Topic #83:
#
# ['nobel', 'premio', 'montagnier', 'pace', 'luc', 'candidati', 'candidato', 'premi', 'prodotto', 'laboratorio']
#
# Topic #373:
#
# ['m5s', 'pd', 'mes', 'governo', 'lega', 'conte', 'peggio', 'solo', 'mov5stelle', 'né']
#
# Topic #411:
#
# ['sapere', 'cos', 'cosa', 'prevenire', 'agisce', 'coronavirus', 'sintomi', 'contagio', 'trasmette', 'proteggersi']
#
# Topic #97:
#
# ['covid_19', 'lombardia', 'veneto', 'reglombardia', '26', '17guariti', 'disp', '735', '25', '29']
#
# Topic #67:
#
# ['kawasaki', 'sindrome', 'malattia', 'bambini', 'legame', 'pediatri', 'bimbi', 'bergamo', 'coronavirus', 'sintomi']
#
# Topic #406:
#
# ['lombardia', 'lombardi', 'coronavirus', 'veneto', 'lombardo', 'matteosalvinimi', 'lombarda', 'emergenza', 'legasalvini', 'solo']
#
# Topic #248:
#
# ['cilento', 'cilentonotizie', 'nuovi', 'casi', 'caso', 'cronaca', 'nuovo', 'vallodidiano', 'alburni', 'annunziata']
#
# Topic #79:
#
# ['paesi', '10', '24', 'ore', 'casi', 'usa', 'italia', 'mondo', 'testa', 'brasile']
#
# Topic #123:
#
# ['ieri', '12diagnosi', '11diagnosi', '1ricoveri', 'lombardiadiagnosi', 'coronavirusdati', '1diagnosi', 'ricoveri', 'lucani', 'ord']
#
# Topic #25:
#
# ['follow', 'ricambia', 'pezzo', 'interessa', 'va', 'buonanotte', 'serata', 'buona', 'ricambi', 'dato']
#
# Topic #316:
#
# ['youtube', 'via', 'coronavirus', 'video', 'tempi', 'adbk', 'tempo', 'messaggio', 'turbamento', 'diffonde']
#
# Topic #130:
#
# ['giorni', 'superfici', '28', 'sopravvive', 'sopravvivere', 'può', 'banconote', 'studio', 'resiste', 'pelle']
#
# Topic #76:
#
# ['comasco', 'varesotto', 'brianza', 'provinciali', 'dati', 'casi', 'provincia', 'oggi', 'contagi', 'coronavirus']
#
# Topic #369:
#
# ['casa', 'uscire', 'state', 'così', 'va', 'quando', 'case', 'fuori', 'tempo', 'chiusi']
#
# Topic #3:
#
# ['interessa', 'pezzo', 'giornata', 'buona', 'ddinopirri', '9bruttapazza7', 'francescovic17', 'delbosco85', 'giuliaaagallo', 'wecanfindaplace']
#
# Topic #450:
#
# ['problema', 'problemi', 'coronavirus', 'soluzione', 'ultimo', 'solo', 'serio', 'risolve', 'sottovalutato', 'risolto']
#
# Topic #415:
#
# ['abruzzo', 'aggiornati', 'dati', 'positivi', 'casi', 'coronavirus', 'maggio', 'aprile', 'luglio', 'tamponi']
#
# Topic #453:
#
# ['calabria', 'rispetto', 'ieri', 'positivi', 'bollettino', 'regione', 'coronavirus', 'gennaio', 'agosto', 'oggi']
#
# Topic #423:
#
# ['toscana', 'morti', 'oggi', 'nuovi', 'contagi', 'casi', 'coronavirus', '22', 'ricoveri', 'inizio']
#
# Topic #92:
#
# ['attuali', 'casi', 'bollettino', 'oggi', 'deceduti', 'dimessi', 'guariti', 'attualmente', '35', 'cas']
#
# Topic #89:
#
# ['italiaprevalenza', 'fonte', 'ministero', 'provincia', 'contagio', 'salute', 'covid19', 'maggio', 'oggi', 'salu']
#
# Topic #183:
#
# ['tg24', 'ultim', 'provincia', 'ora', 'frosinone', 'positivi', 'nuovi', 'casi', 'decessi', 'regione']
#
# Topic #125:
#
# ['infor', 'coronavirusitalia', 'giornalieri', 'andamento', 'covid19italia', 'italia', 'decessi', '12', 'covid19', '20']
#
# Topic #352:
#
# ['regole', 'rispettare', 'rispetta', 'rispettano', 'rispetto', 'valgono', 'rispettato', 'gente', 'rispettarle', 'multe']
#
# Topic #451:
#
# ['sicilia', 'morti', 'nuovi', 'casi', 'catania', 'coronavirus', 'guariti', '34', 'provincia', 'messina']
#
# Topic #144:
#
# ['nave', 'giappone', 'crociera', 'quarantena', 'bordo', 'italiani', '35', 'kong', 'hong', 'passeggeri']
#
# Topic #219:
#
# ['presidente', 'president', 'bravo', 'grande', 'grazie', 'for', 'cuomo', 'sopo', 'narciso', 'sempre']
#
# Topic #98:
#
# ['danimarca', 'visoni', 'milioni', '17', 'mutato', 'abbatterà', 'allevamenti', 'abbattimento', 'mutazione', 'abbattuti']
#
# Topic #88:
#
# ['temperatura', 'termometro', 'misurazione', 'corporea', 'misurare', 'febbre', 'termoscanner', 'rilevazione', 'covid19', 'epidemia']
#
# Topic #165:
#
# ['tv', 'intervista', 'speciale', 'servizio', 'coronavirus', 'procida', 'lembo', 'isola', 'onda', 'ischia']
#
# Topic #300:
#
# ['coronavirus', 'nuovo', 'via', 'oms', 'pandemia', 'cigno', 'può', 'sapone', 'così', 'importante']
#
# Topic #45:
#
# ['unità', 'crisi', 'campania', 'aggiornamento', '2020', 'agosto', 'novembre', 'coronavirus', 'giugno', 'maggio']
#
# Topic #180:
#
# ['petroliferi', 'impianti', 'basilicata', 'eni', 'chiuso', 'fca', 'shell', 'disastro', 'total', 'petrolio']
#
# Topic #275:
#
# ['spagna', 'morti', 'oltre', 'contagi', 'mondo', 'ore', 'coronavirus', '24', 'vittime', 'mila']
#
# Topic #431:
#
# ['pazzo', 'pazzi', 'idioti', 'insanity', 'idiota', 'follia', 'vergognoso', 'insane', 'loco', 'roba']
#
# Topic #357:
#
# ['articolo', 'leggere', 'articoli', 'condivisibile', 'letto', 'scritto', 'bell', 'poi', 'così', 'molto']
#
# Topic #232:
#
# ['dimenticare', 'ricordarlo', 'ricordi', 'ricordiamo', 'ricordare', 'ricorda', 'dimenticati', 'memoria', 'ricordo', 'mai']
#
# Topic #185:
#
# ['democrazia', 'democratico', 'comunisti', 'comunista', 'comunismo', 'coronavirus', 'virus', 'fa', 'cina', 'dittatura']
#
# Topic #308:
#
# ['referendum', 'elezioni', 'taglio', 'parlamentari', 'voto', 'rinviato', 'rinvio', 'amministrative', 'regionali', 'parlamento']
#
# Topic #206:
#
# ['congress', 'mobile', 'world', 'barcellona', 'cancellato', 'mwc', '2020', 'fiera', 'lg', 'telefonia']
#
# Topic #317:
#
# ['normalità', 'normale', 'ritorno', 'tornare', 'vita', 'quando', 'normali', 'torneremo', 'tornerà', 'ritornare']
#
# Topic #425:
#
# ['600', 'euro', 'bonus', 'inps', 'autonomi', 'gualtieri', 'aprile', 'indennità', 'coronavirus', 'iva']
#
# Topic #288:
#
# ['dati', 'italia', 'oggi', 'aprile', 'febbraio', 'aggiornamenti', 'marzo', 'giovedì', 'venerdì', 'notizie']
#
# Topic #129:
#
# ['edite', 'post', 'veneto', 'ricoveri', 'decessi', 'covid', 'contagi', 'calo', 'giornata', 'ricoverati']
#
# Topic #38:
#
# ['coronainfoch', 'contano', 'confermati', 'attualmente', 'laboratorio', 'casi', 'instensiva', '18', 'ricoverati', 'sintomi']
#
# Topic #322:
#
# ['discoteche', 'chiuse', 'chiudere', 'aperte', 'estate', 'chiusura', 'discotechechiuse', 'disco', 'chiuso', 'andavano']
#
# Topic #313:
#
# ['nazionali', '2020', '19', 'dati', 'covid', 'voce', '2021', 'news', 'dicembre', 'novembre']
#
# Topic #8:
#
# ['bianconero', 'anch', 'ricambia', 'nuoro', 'follow', 'oristano', 'interessa', 'cagliari', 'sud', 'va']
#
# Topic #14:
#
# ['scuso', 'mandato', 'pezzo', 'interessa', 'già', 'pomeriggio', 'buon', 'buona', 'giornata', 'ricambia']
#
# Topic #91:
#
# ['today', 'toscana', 'ausltoscana', 'nuovi', 'guariti', 'isolamentocoronavirus', 'casi', 'dati', 'contagio', 'isolamento']
#
# Topic #47:
#
# ['romagna', 'emilia', 'aggiornamenti', 'emiliaromagnago', 'dati', '2020', '2021', 'luglio', 'agosto', 'gennaio']
#
# Topic #438:
#
# ['fume', 'arrepiei', 'lasquei', 'chispoteo', 'boh', 'tremando', 'commuovo', 'bho', 'ammazzo', 'commosso']
#
# Topic #108:
#
# ['radio', 'maria', 'livio', 'satana', 'radiomaria', 'criminale', 'complotto', 'progetto', 'padre', 'impulso']
#
# Topic #400:
#
# ['salvini', 'coronavirus', 'matteosalvinimi', 'colpa', 'fatto', 'lega', 'attacca', 'stato', 'cosa', 'sempre']
#
# Topic #196:
#
# ['caffè', 'bar', 'caffe', 'covid19', 'buongiorno', 'colazione', 'buon', 'pausa', 'café', 'coffee']
#
# Topic #103:
#
# ['nobel', 'montagnier', 'premio', 'laboratorio', 'luc', 'manipolato', 'medicina', 'wuhan', 'rilasciato', 'creato']
#
# Topic #226:
#
# ['zelanda', 'nuova', 'sconfitto', 'lockdown', 'olanda', 'auckland', 'coronavirus', 'giorni', 'victoria', 'australia']
#
# Topic #273:
#
# ['luis', 'scrittore', 'sepulveda', 'cileno', 'morto', 'sepúlveda', 'contratto', 'ucciso', 'addio', '70']
#
# Topic #428:
#
# ['commenti', 'commentare', 'commento', 'letto', 'leggendo', 'comentarios', 'los', 'appena', 'cosa', 'commenta']
#
# Topic #66:
#
# ['ausl', 'territori', 'centro', 'toscana', 'nuovi', 'casi', 'castelbolognese', 'decessi', 'provincia', 'regione']
#
# Topic #443:
#
# ['24', 'ore', 'decessi', 'nuovi', 'casi', 'coronavirus', '13', '10', '17', '14']
#
# Topic #272:
#
# ['38enne', 'ricoverato', 'codogno', 'contagiato', 'primo', 'lombardia', 'italiano', 'contagio', 'caso', 'milano']
#
# Topic #117:
#
# ['enna', 'soggetti', 'positivi', 'provincia', 'dicembre', 'aprile', 'novembre', 'meno', 'marzo', 'coronavirus']
#
# Topic #68:
#
# ['lupo', 'bocca', 'pelo', 'vizio', 'perde', 'forza', 'massimgiannini', 'maturandi', 'grande', 'covid19']
#
# Topic #212:
#
# ['nord', 'sud', 'settentrionali', 'affitta', 'coronavirus', 'walter', 'esodo', 'ricciardi', 'regioni', 'chiude']
#
# Topic #27:
#
# ['nuovi', 'deceduti', 'totale', 'rovigo', 'belluno', 'vicenza', 'guariti', 'venezia', 'nu', 'contagi']
#
# Topic #131:
#
# ['giuliani', 'rudy', 'tests', 'trump', 'for', 'positive', 'positivo', 'abogado', '19', 'covid']
#
# Topic #175:
#
# ['comitato', 'scientifico', 'tecnico', 'verbali', 'atti', 'segreto', 'governo', 'coronavirus', 'desecretati', 'cts']
#
# Topic #86:
#
# ['birra', 'corona', 'marchio', 'colpito', 'coronavirus', 'ghiacciata', 'assurdo', '103', 'assonanza', 'beer']
#
# Topic #15:
#
# ['incremento', 'genova', 'totali', 'unità', 'politi_do', 'aggiornamento', 'provincia', 'maggiori', 'segui', 'top']
#
# Topic #247:
#
# ['teatri', 'cinema', 'teatro', 'spettacolo', 'spettacoli', 'appello', 'coronavirus', 'vivo', 'cultura', 'palestre']
#
# Topic #120:
#
# ['deceduti', 'dimessi', 'attualmente', 'guariti', 'positivi', '21', '20', '35', 'attuali', '03']
#
# Topic #279:
#
# ['sindaco', 'città', 'sciistici', 'fatto', 'così', 'beppesala', 'ferrara', 'leghista', 'impianti', 'quando']
#
# Topic #135:
#
# ['diramato', 'salutelazio', 'medico', 'inmispallanzani', 'bollettino', 'inmi', 'spallanzani', 'coronavirusitalia', 'coronavirus', '20aprile']
#
# Topic #237:
#
# ['meta_magazine', 'carlocolizza', 'frascati', 'marino', 'comunisti', 'regionelazio', 'meta', 'sindacomarini', 'nicolagallo80', 'dariacontrada']
#
# Topic #340:
#
# ['strategia', 'strategie', 'strategica', 'sempre', 'blindarci', 'stessa', 'mesi', 'early', 'può', 'gestionale']
#
# Topic #251:
#
# ['america', 'usa', 'number', 'ghetto', 'one', 'we', 'is', 'decline', 'so', 'americano']
#
# Topic #163:
#
# ['scrittura', 'covid2019', 'giorno', 'covid_19', 'covid19', 'covid', 'coronavirus', 'covid19italia', 'covid_2019', 'coronavirusitalia']
#
# Topic #94:
#
# ['emilia', 'romagna', 'regione', 'sbonaccini', 'covid19', 'emiliaromagna', 'ordinanza', 'bonaccini', 'presidente', 'regioneer']
#
# Topic #41:
#
# ['nononononononononononononononononononononononononononononononononononononononononononononononononononononononononon', 'noooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooonnnononononono', 'jajsjdjjdjsjdjsjahdjsjajhajshsjs', 'ahahahahhahahhahhahahhahahahhahahahhahahahhahahahhahahahhahahahahhahahahhahahahhahahahahahhahahahhahahahhahhahahhah', 'hahahahhahahahhahahahahahaahahahhahahahahhahahahahahahahhahahahhaahhaahhahahahhahhahahahhahahahahahhahahahahhahahah', 'osbrofjdnskrodkdnsjsorkfjxisjdjdfjxosjfjfksoajsjfofisjdjfodisjdjfksidhfkdisjrjtkfidhdjfkdjdjdjdjdhdiddjsjshwkeksj', 'hahahahhahahahhahahhahahhahahahhahahahhahhahahavhahahahhahavhahahahhahahahahhahahahhahahahhahahhahahahhahahahhahahh', 'bsiabakgakabskshskbsjsbsjsbkkkkshaoahkahsksbsjshsihaoahajabkabsksjsksblabsksjjsjsjjsjsjklllllllshskbalsbslsbwlshslg', 'skfodjwjcjsbsichwbxjxkcjsbskcjdjcncjsjdjshskcjwldovifhwgauavagfockkbsodvjdjdiwkhfjccdihdcojfodjcjdhdjd', 'hdbdhbzbsnshshbsbshzhvzhzbxbhzbhzbzhzbhzbzhsbzhnzhxbzhzbzgzbzgzhhsnzjzmzkzmxkxmxkxkmdkxmxksmsksmkskskskskskskskskks']
#
# Topic #187:
#
# ['raggi', 'uv', 'ultravioletti', 'secondi', 'disattivato', 'studio', 'uccidono', 'sole', 'luce', 'ultravioletta']
#
# Topic #161:
#
# ['pagina', 'leggi', 'prima', 'mattino', 'lt', 'gt', 'messaggero', 'stretta', 'napoli', 'messaggeroscuola']
#
# Topic #447:
#
# ['lombardia', 'bollettino', 'positivi', 'nuovi', 'oggi', 'morti', 'gennaio', 'giugno', 'dicembre', 'vittime']
#
# Topic #458:
#
# ['covi', 'bollettino', 'contagi', 'dati', 'morti', 'oggi', 'italia', 'fanpage', 'tamponi', 'giovedì']
#
# Topic #342:
#
# ['grazie', 'mille', 'invernizzi', 'isaia', 'ringraziate', 'officialasroma', 'easyinve', 'sig', 'liviograzie', 'fmonderna']
#
# Topic #349:
#
# ['iorestoacasa', 'covid19', 'covid_19', 'stoacasamiacomelombardia', 'iostoacasa', 'stoacasa', 'stayathome', 'quarantine', 'stayhome', 'gt']
#
# Topic #295:
#
# ['degenza', 'aretino', 'intensiva', 'terapia', 'guarite', 'persone', 'nuovi', 'casi', 'decess', 'covid']
#
# Topic #243:
#
# ['treni', 'treno', 'sud', 'distanziamento', 'trenitalia', 'nord', 'percorrenza', 'stazione', 'lunga', 'posti']
#
# Topic #93:
#
# ['emilia', 'aggiornamento', 'modenese', 'decessi', 'nuovi', 'casi', 'bassa', 'nessun', 'decesso', 'nuovo']
#
# Topic #101:
#
# ['conteggiocontagio', 'propagandalive', 'facciamorete', 'covid19', 'coronavirus', 'covid19italy', 'cui1408686', 'welikeduel1455022', 'propagandalive3904899', 'welikeduel1408868']
#
# Topic #139:
#
# ['palermo', 'covid19', 'blogsicilianotizie', '19', 'covid', 'positivi', 'positivo', 'controlli', 'villabate', 'provincia']
#
# Topic #427:
#
# ['leggere', 'leggete', 'lettura', 'consiglio', 'assolutamente', 'attentamente', 'attenzione', 'bene', 'prego', 'favore']
#
# Topic #207:
#
# ['matrimonio', 'matrimoni', 'nozze', 'sposa', 'invitati', 'sposi', 'coronavirus', 'quarantena', '76', 'palmas']
#
# Topic #43:
#
# ['dinosauri', 'uomo', 'bano', 'distrutto', 'capace', 'albano', 'distruggere', 'distruggerà', 'figuriamoci', 'domenicain']
#
# Topic #250:
#
# ['19', 'covid', 'euro', 'milioni', 'miliardi', 'fondo', 'emergenza', 'causa', 'deflussi', 'costato']
#
# Topic #303:
#
# ['19', 'ospedale', 'covid', 'pazienti', 'policlinico', 'reparto', 'ospedali', 'medici', 'riuniti', 'infermieri']
#
# Topic #124:
#
# ['regione', 'fornito', 'riepilogo', 'ufficiale', 'diffusione', '2020', '2021', '03', '12', 'riferiti']
#
# Topic #63:
#
# ['data', '2021', 'regione', 'nuovi', 'accertati', 'rassegna', 'comunicato', 'tamponi', 'casi', 'marzo']
#
# Topic #30:
#
# ['eep', 'nazionalismi', 'opposti', 'europa', 'sfida', 'debito', 'pubblico', 'eepentezza', 'default', 'europea']
#
# Topic #28:
#
# ['trani', 'barletta', 'andria', 'corsa', 'brindisi', 'lecce', 'taranto', 'lazio', 'veneto', 'romagna']
#
# Topic #16:
#
# ['irlanda', 'alternativa', '19', 'eep', 'arriverà', 'covid', 'ripresa', 'italia', 'bagnai', 'scenari']
#
# Topic #69:
#
# ['miley', 'cyrus', 'conte', 'bimba', 'giuseppe', 'mileycyrus', 'risponde', 'montana', 'giuseppi', 'hannah']
#
# Topic #347:
#
# ['milano', 'coronavirus', 'coronavirusitalia', 'milanononsiferma', 'tempi', 'covid19', 'covid19italia', 'tempo', 'così', 'esselunga']
#
# Topic #176:
#
# ['giulia', 'friuli', 'venezia', 'tgr', 'fvg', 'regione', 'fedriga', 'coronavirus', 'zona', 'decreta']
#
# Topic #444:
#
# ['sicilia', 'positivi', 'morti', 'nuovi', 'guariti', 'casi', 'coronavirus', 'oggi', 'vittime', '24']
#
# Topic #109:
#
# ['robot', 'robotica', 'covid19', 'corsia', 'futuro', 'covid', '19', 'lhf', 'connect', 'droni']
#
# Topic #39:
#
# ['riepilogo', 'disposizioni', 'contenimento', 'contagio', 'coronavirusitalia', '05', 'italia', 'casi', '20', '02']
#
# Topic #364:
#
# ['anno', 'ano', 'fa', 'sana', 'desse', 'anni', 'quest', 'buon', 'esse', 'po']
#
# Topic #201:
#
# ['tabelle', 'campania', 'irpinia', 'positivi', 'salgono', '19', 'nuova', 'covid', 'morti', 'via']
#
# Topic #35:
#
# ['evoluzione', 'palazzo_chigi', 'welikeduel', 'coronvirusitalia', 'dpcgov', '20', 'pispico', 'bardo', 'quaderni', 'covid19italia']
#
# Topic #87:
#
# ['venezia', 'veneto', 'provincia', 'numeri', 'bollettino', 'serale', 'gt', 'febbraio', 'gennaio', 'dicembre']
#
# Topic #18:
#
# ['tot', 'reggio', 'sintomatici', 'giornata', 'decessi', 'nuovi', 'casi', '595', 'emilia', 'coronavirus']
#
# Topic #231:
#
# ['statistiche', 'statistica', 'ragionevoli', 'razionali', 'tabelle', 'insomma', 'vuol', 'far', 'tanto', 'fluttuazione']
#
# Topic #33:
#
# ['esagerata', 'rizzo', 'inizialmente', 'marco', 'fatta', 'comunicazione', 'stata', 'coronavirus', '19ncov', 'livepaola']
#
# Topic #407:
#
# ['vaccino', 'efficace', 'pfizer', 'astrazeneca', 'moderna', 'efficacia', '90', 'ema', '95', '94']
#
# Topic #110:
#
# ['karma', 'chiama', 'covid19', 'bitch', 'vedi', 'is', 'briatore', 'gran', 'altrui', 'sempre']
#
# Topic #99:
#
# ['zombie', 'zombi', 'apocalypse', 'apocalisse', 'film', 'zombies', 'trasformati', 'covid19', 'finalmente', 'apocalissi']
#
# Topic #241:
#
# ['deceduti', 'siena', 'toscana', 'positivi', 'nuovi', 'casi', '27', '10', 'coronavirus', '22']
#
# Topic #106:
#
# ['fascismo', 'fascisti', 'fascista', 'mussolini', 'sgarbi', 'confinamento', 'asintomatici', 'coronavirus', 'camera', 'antifascista']
#
# Topic #292:
#
# ['story', 'marzo', '2020', 'febbraio', '2020la', 'pagina', '2020a', 'prima', 'michelebocci1', 'coronavirus']
#
# Topic #257:
#
# ['rossa', 'zona', 'rosse', 'zonarossa', 'zone', 'colori', 'colore', 'regioni', 'covid19', 'andare']
#
# Topic #112:
#
# ['provincia', 'italiala', 'casi', 'percentuale', 'registrato', 'nuovi', 'alta', 'abitanti', 'contagio', 'covid19']
#
# Topic #37:
#
# ['inps', 'selezionate', 'alert', 'google', 'cdmx', 'descenso', '19', 'cassa', 'covid', '2020']
#
# Topic #31:
#
# ['mercato', 'eep', 'fallimenti', 'paradosso', 'debito', 'prezzi', 'sanitaria', 'spesa', 'europa', 'pubblico']
#
# Topic #40:
#
# ['diramato', 'salutelazio', 'inmispallanzani', 'medico', 'bollettino', 'inmi', 'spallanzani', 'coronavirus', 'ministerosalute', 'rt']
#
# Topic #42:
#
# ['chiavecoronavirus', 'parole', 'news', 'ultime', 'chiavecovid19', 'coronaviruscovid19', 'covid19covid19', 'covid19trump', 'coronavirus2020', '2020covid19']
#
# Topic #297:
#
# ['spallanzani', 'intensival', 'inmi', 'pazienti', 'terapia', 'ricoverati', 'diramato', 'positivi', 'intensiva', 'istituto']
#
# Topic #299:
#
# ['musica', 'vivo', 'music', 'live', 'film', 'covid19', 'album', 'cantautore', 'teatro', 'musicali']
#
# Topic #61:
#
# ['aiutialleimprese', 'nazionale', 'decretorilancio', 'covid19', 'contributi', 'bonus', 'domande', 'coronavirus', 'aiuti', 'fondo']
#
# Topic #29:
#
# ['classifica', 'aggiornata', 'diffusori', 'profili', 'province', 'super', 'covid19italia', 'twitter', 'fake', 'italiani']
#
# Topic #392:
#
# ['interessante', 'interesante', 'molto', 'interessant', 'dato', 'interesantisimo', 'davvero', 'avance', 'sempre', 'pone']
#
# Topic #146:
#
# ['mani', 'lavarsi', 'igiene', 'gesto', 'mondiale', 'giornata', 'covid19', 'lavaggio', 'sapone', 'spesso']
#
# Topic #72:
#
# ['policlinico', 'pazienti', 'ricoverati', 'biomedico', 'campus', 'terapia', 'intensiva', 'ospedaliera', 'vergata', 'azienda']
#
# Topic #361:
#
# ['tempi', 'tempo', 'coronavirus', 'distanza', 'alimentare', 'spot', 'prepartita', 'belliche', 'straniata', 'civetterie']
#
# Topic #310:
#
# ['mercati', 'economia', 'impatto', 'effetti', 'finanziari', 'coronavirus', 'effetto', 'finanzaemercati', 'economico', 'torna']
#
# Topic #268:
#
# ['anziani', 'coronavirus', 'rsa', 'carabinieri', 'case', 'assistenza', 'domicilio', 'strage', 'spesa', 'consegnano']
#
# Topic #195:
#
# ['memoria', 'vittime', 'giornata', 'nazionale', 'epidemia', '18', 'marzo', '18marzo', 'oggi', 'ricordo']
#
# Topic #306:
#
# ['terapia', 'intensiva', 'intensive', 'terapie', 'massimgiannini', 'posti', 'pazienti', 'numero', 'dato', 'scrive']
#
# Topic #260:
#
# ['produttivo', 'sforzo', 'indispensabili', 'paese', 'indispensabile', 'toti', 'persone', 'produzione', 'giovannitoti', 'persona']
#
# Topic #168:
#
# ['italia', 'guariti', 'bollettino', 'morti', 'positivi', 'casi', 'dicembre', 'deceduti', 'coronavirus', 'abruzzo']
#
# Topic #49:
#
# ['trento', 'provincia', 'dati', 'tamponi', 'analizzati', 'positivi', 'testrapidi', 'covid19', 'autonoma', 'morti']
#
# Topic #71:
#
# ['luogocomune', 'meluzzi', 'sbalorditive', 'complotto', 'dintorni', 'coincidenze', 'parla', 'coronavirus', 'posizione', 'emergenza']
#
# Topic #70:
#
# ['forzedipolizia', 'controlli', 'persone', 'verificato', 'anti', 'sanzionate', 'misure', 'covid19', 'verifiche', 'controllate']
#
# Topic #155:
#
# ['tecnico', 'comitato', 'scientifico', 'verbali', 'riunione', 'spadafora', 'comitatotecnicoscientifico', 'incontro', 'riunioni', 'coordinatore']
#
# Topic #151:
#
# ['19', 'covid', 'positivo', 'caso', 'positività', 'nessun', 'viterbo', 'positivi', 'accertato', 'nuovo']
#
# Topic #78:
#
# ['gerry', 'scotti', 'positivo', 'dirvelo', 'casa', 'intensiva', 'terapia', 'volevo', 'gerryscotti', 'controllo']
#
# Topic #252:
#
# ['paese', 'nazionali', 'paesi', 'merda', 'patria', 'trovi', 'amo', 'nazione', 'traditore', 'civile']
#
# Topic #36:
#
# ['xviii', 'legislatura', 'frosinone', 'definitivo', 'unione', 'senato', 'atto', 'asl', 'europea', 'comuni']
#
# Topic #294:
#
# ['morto', '19', 'covid', 'muore', 'anni', 'scaccia', 'covid19', 'pino', 'muoiono', 'morte']
#
# Topic #10:
#
# ['colpiti', 'sale', 'paesi', 'pandemia', 'mondo', 'decessi', 'morti', 'nuovi', 'coronavirus', '584']
#
# Topic #452:
#
# ['sicilia', 'nuovi', 'casi', 'decessi', 'coronavirus', 'catania', 'tamponi', 'siracusa', 'contagi', '984']
#
# Topic #148:
#
# ['matematica', 'opinione', 'quando', 'matematici', 'matematico', 'esponenziale', 'cosa', 'chissà', 'mai', 'ok']
#
# Topic #384:
#
# ['giuseppeconteit', 'fasciocomunista', 'governo', 'nzingaretti', 'robersperanza', 'inetti', 'matteorenzi', 'governodellavergogna', 'coronavirus', 'governodelcontagio']
#
# Topic #214:
#
# ['2021', 'vaccino', 'entro', '2020', '2022', 'fauci', 'fine', 'coronavirus', 'prima', 'speranza']
#
# Topic #296:
#
# ['cinema', 'teatri', 'teatro', 'biglietti', 'chiusi', 'concerti', 'dariofrance', 'spettacoli', 'tizianoferro', 'ovvero']
#
# Topic #145:
#
# ['disney', 'disneyland', 'world', 'california', 'parchi', 'orlando', 'walt', 'centro', 'florida', 'disneyworld']
#
# Topic #336:
#
# ['criminali', 'negligent', 'criminally', 'criminal', 'criminale', 'crimine', 'homicide', 'criminel', 'assassini', 'negligence']
#
# Topic #290:
#
# ['2020', 'edizione', 'emergenza', 'coronavirus', 'pebble', 'siae', 'maturità', '2021', 'estate', 'rinviato']

# %%
# Out:
# 372

# %%
import matplotlib.pyplot as plt
from datetime import datetime


text_raw_df['dates'] =  text_raw_df['publication_date'].apply(lambda x:  datetime.fromtimestamp(x))
text_raw_df['Topic'] = cluster.labels_
text_raw_df


for num_topic in topic_sizes['Topic']:
    ax = text_raw_df.groupby([text_raw_df['Topic'], text_raw_df['dates'].dt.year, text_raw_df['dates'].dt.month]).count()['id'][num_topic].plot(kind="bar") #Imprime el topic cero
    ax.grid(b=True, axis='both')
    #print(type(ax))
    ax.set_title('Distribución del Topic ' + str(num_topic) + ' en los documentos en inglés')
    ax.set_xlabel('Mes y año de los tweets')
    ax.set_ylabel('Número de tweets del topic')
    plt.show()
