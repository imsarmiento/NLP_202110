# %% [markdown]
# # Punto 1 - Italian
# ## Automatic identification of “trending/viral” topics around COVID in time in the World using deep learning architectures. Type: Different approaches.

# %%
import pickle as pk
import pandas as pd
import numpy as np
import json
from sklearn.feature_extraction.text import CountVectorizer
from stop_words import get_stop_words
import umap.umap_ as umap

# %% [markdown]
# ## Files used
# The datasets and the embedings generated with a pretrained Sentence Bert model

# %%
#prefix = './drive/MyDrive/'
prefix = ''
italian_path = prefix + 'datasets/italian/italian_out_hash_bien.json'

#prefix = './drive/MyDrive/'
prefix = ''
italian_embeddings_path = prefix + 'models_hpc/embeddings_ita_v2.pickle'

#prefix = './drive/MyDrive/'
prefix = ''
umap_italian_embeddings_path = prefix + 'models_hpc/umap_ita_v2.pickle'

# %%
file = open(italian_path, 'r')
data = []
for line in file:
    data.append(json.loads(line))
text_raw_df = pd.json_normalize(data)

print(text_raw_df.shape)
text_raw_df.head(10)
# Out:
# (814485, 4)
#                     id  publication_date   source  \
# 0  1324811856859533313      1.604695e+09  twitter
# 1  1288746494368124928      1.596096e+09  twitter
# 2  1326191597785059329      1.605024e+09  twitter
# 3  1275134048722132993      1.592851e+09  twitter
# 4  1243118079091118080      1.585217e+09  twitter
# 5  1267645840455278594      1.591065e+09  twitter
# 6  1233340720460726272      1.582886e+09  twitter
# 7  1279712208612667393      1.593942e+09  twitter
# 8  1271709738301095936      1.592034e+09  twitter
# 9  1296853994686513152      1.598029e+09  twitter
#
#                                                 text
# 0  Il prof. #Galli è molto preoccupato da quanto ...
# 1  Il COVID-19 coincide con un momento cruciale n...
# 2  Muoviamoci #vaccinoCovid #coronavirus #COVID19...
# 3  @mosllerdd @Cartabellotta Si sarebbero potute ...
# 4  @morzo6 @CNN Purtroppo sì. State a casa. Disin...
# 5  @orticArya * "il coronavirus non c'è più, ma c...
# 6  Coronavirus, l’ultima trovata: mascherine grif...
# 7  "Penne in quarantena". Tredici #racconti di al...
# 8  Cina, torna l’incubo Coronavirus: alcuni quart...
# 9                                 Questo è il punto

# %%
'''
Turn text to Numpy Array
'''
texts_column = text_raw_df.loc[:,'text']
raw_texts = texts_column.values
raw_texts[0]
# Out:
# 'Il prof. #Galli è molto preoccupato da quanto sta accadendo a #Milano '

# %%
#with open(italian_embeddings_path, "rb") as output_file:
#    embeddings = pk.load(output_file)

with open(umap_italian_embeddings_path, "rb") as output_file:
    umap_embeddings = pk.load(output_file)


with open("models_hpc/umap_ita_graph.pickle", "rb") as output_file:
    umap_graph = pk.load(output_file)

# %% [markdown]
# ### HDBSCAN para el clustering

# %%
import hdbscan
cluster = hdbscan.HDBSCAN(min_cluster_size=70,
                          metric='euclidean',
                          cluster_selection_method='eom',
                          min_samples=300).fit(umap_embeddings)

# %% [markdown]
# ### Visualisación de los clusters

# %%
import matplotlib.pyplot as plt

# Prepare data
umap_data = umap_graph
result = pd.DataFrame(umap_data, columns=['x', 'y'])
result['labels'] = cluster.labels_

# Visualize clusters
fig, ax = plt.subplots(figsize=(20, 10))
outliers = result.loc[result.labels == -1, :]
clustered = result.loc[result.labels != -1, :]
plt.scatter(outliers.x, outliers.y, color='#BDBDBD', s=0.05)
plt.scatter(clustered.x, clustered.y, c=clustered.labels, s=0.05, cmap='hsv_r')
plt.colorbar()

# %% [markdown]
# ### c-TF-IDF

# %%
docs_df = pd.DataFrame(raw_texts, columns=["Doc"])
docs_df['Topic'] = cluster.labels_
docs_df['Doc_ID'] = range(len(docs_df))
docs_per_topic = docs_df.groupby(['Topic'], as_index = False).agg({'Doc': ' '.join})

# %%
def c_tf_idf(documents, m, ngram_range=(1, 1)):
    count = CountVectorizer(ngram_range=ngram_range, stop_words=get_stop_words('italian')).fit(documents)
    t = count.transform(documents).toarray()
    w = t.sum(axis=1)
    tf = np.divide(t.T, w)
    sum_t = t.sum(axis=0)
    idf = np.log(np.divide(m, sum_t)).reshape(-1, 1)
    tf_idf = np.multiply(tf, idf)

    return tf_idf, count

tf_idf, count = c_tf_idf(docs_per_topic.Doc.values, m=len(raw_texts))

# %%
def extract_top_n_words_per_topic(tf_idf, count, docs_per_topic, n=20):
    words = count.get_feature_names()
    labels = list(docs_per_topic.Topic)
    tf_idf_transposed = tf_idf.T
    indices = tf_idf_transposed.argsort()[:, -n:]
    top_n_words = {label: [(words[j], tf_idf_transposed[i][j]) for j in indices[i]][::-1] for i, label in enumerate(labels)}
    return top_n_words

def extract_topic_sizes(df):
    topic_sizes = (df.groupby(['Topic'])
                     .Doc
                     .count()
                     .reset_index()
                     .rename({"Topic": "Topic", "Doc": "Size"}, axis='columns')
                     .sort_values("Size", ascending=False))
    return topic_sizes

top_n_words = extract_top_n_words_per_topic(tf_idf, count, docs_per_topic, n=20)
topic_sizes = extract_topic_sizes(docs_df);
topic_sizes.head(10)
# Out:
#      Topic    Size
# 0       -1  518352
# 126    125   30339
# 129    128   20123
# 65      64   17957
# 109    108   17945
# 56      55   15967
# 119    118   15004
# 22      21   12378
# 122    121   11895
# 76      75    8450

# %%
len(topic_sizes)
# Out:
# 152

# %%
for topic in topic_sizes['Topic']:
  if topic == -1:
    continue
  print('Topic #' + str(topic) +":"+ '\n')
  print(str([t[0] for t in top_n_words[topic][:10]]) + '\n')
# Out:
# Topic #125:
#
# ['coronavirus', 'virus', 'covid19', 'coronavirusitalia', 'solo', 'cosa', 'quando', 'fa', 'covid_19', 'fatto']
#
# Topic #128:
#
# ['sempre', 'bene', 'cazzo', 'cosa', 'così', 'quando', 'eh', 'solo', 'proprio', 'mai']
#
# Topic #64:
#
# ['coronavirus', 'covid', '19', 'positivi', 'casi', 'emergenza', 'nuovi', 'italia', 'abruzzo', 'covid19']
#
# Topic #108:
#
# ['covid19', '19', 'covid', 'emergenza', 'crisi', 'dopo', 'lavoro', 'tempi', 'cosa', 'solo']
#
# Topic #55:
#
# ['calcio', 'positivo', '19', 'covid', 'serie', 'sport', 'positivi', 'coronavirus', 'inter', 'seriea']
#
# Topic #118:
#
# ['vaccino', 'vaccini', 'covid19', 'covid', 'anti', '19', 'astrazeneca', 'pfizer', 'vaccinazione', 'vaccinazioni']
#
# Topic #21:
#
# ['cina', 'cinese', 'cinesi', 'coronavirus', 'pechino', 'wuhan', 'china', 'italia', 'virus', 'oms']
#
# Topic #121:
#
# ['giuseppeconteit', 'matteosalvinimi', 'robersperanza', 'robertoburioni', 'cartabellotta', 'corriere', 'giorgiameloni', 'cosa', 'borghi_claudio', 'solo']
#
# Topic #75:
#
# ['medici', 'sanità', 'covid19', 'medico', 'ospedali', 'ospedale', 'salute', 'infermieri', 'pazienti', 'covid']
#
# Topic #127:
#
# ['governo', 'italia', 'italiani', 'ministro', 'politica', 'paese', 'governodellavergogna', 'italiano', 'stato', 'quando']
#
# Topic #145:
#
# ['positivi', 'nuovi', 'positivo', 'coronavirus', 'tamponi', 'casi', 'campania', 'calabria', 'oggi', 'bollettino']
#
# Topic #34:
#
# ['scuole', 'scuola', 'chiuse', 'coronavirus', 'chiusura', 'azzolina', 'marzo', 'università', 'riapertura', 'didattica']
#
# Topic #40:
#
# ['trump', 'usa', 'biden', 'donald', 'coronavirus', 'presidente', 'covid19', 'bianca', 'fauci', 'mondo']
#
# Topic #143:
#
# ['coronavirus', 'conte', 'governo', 'misure', 'emergenza', 'ondata', 'speranza', 'via', 'burioni', 'lockdown']
#
# Topic #60:
#
# ['morti', 'covid19', '000', 'morte', 'covid', 'persone', 'giorno', 'oggi', 'morto', 'muore']
#
# Topic #149:
#
# ['morti', 'nuovi', 'casi', 'bollettino', 'italia', 'oggi', '24', 'ultime', 'coronavirus', 'vittime']
#
# Topic #78:
#
# ['morto', 'anni', 'muore', 'vittima', 'coronavirus', 'morta', 'donna', 'uomo', 'primo', 'ricoverato']
#
# Topic #86:
#
# ['mascherina', 'mascherine', 'indossare', 'covid19', 'guanti', 'aperto', 'naso', 'uso', 'obbligo', 'distanziamento']
#
# Topic #107:
#
# ['roma', 'coronavirus', 'spallanzani', 'via', 'romani', 'romano', 'piazza', 'raggi', 'capitale', 'mascherine']
#
# Topic #132:
#
# ['mondo', 'milioni', 'morti', 'oltre', 'usa', 'casi', 'mila', 'coronavirus', 'contagi', '000']
#
# Topic #97:
#
# ['europa', 'ue', 'europea', 'europei', 'europeo', 'covid19', 'unione', 'paesi', 'euro', 'crisi']
#
# Topic #56:
#
# ['europa', 'ue', 'coronavirus', 'europea', 'europeo', 'europei', 'italia', 'unione', 'paesi', 'eurogruppo']
#
# Topic #11:
#
# ['animali', 'cani', 'cane', 'gatti', 'animale', 'coronavirus', 'carne', 'gatto', 'domestici', 'zoo']
#
# Topic #38:
#
# ['piemonte', 'contagi', 'coronavirus', 'nuovi', 'bollettino', 'decessi', 'guariti', 'casi', 'regione', 'cirio']
#
# Topic #61:
#
# ['papa', 'chiesa', 'francesco', 'vaticano', 'vatican', 'chiese', 'preghiera', 'coronavirus', 'messa', 'papafrancesco']
#
# Topic #130:
#
# ['lombardia', 'milano', 'coronavirus', 'fontana', 'sala', 'regione', 'gallera', 'contagi', 'via', 'bergamo']
#
# Topic #33:
#
# ['scuola', 'scuole', 'covid19', 'riapertura', 'studenti', 'chiuse', 'azzolina', 'riaprire', 'dad', 'scolastico']
#
# Topic #65:
#
# ['lockdown', 'lockdown2', 'covid19', 'lockdownitalia', 'nuovo', 'dpcm', 'dopo', 'durante', 'mesi', 'conte']
#
# Topic #43:
#
# ['voli', 'aereo', 'volo', 'aerei', 'passeggeri', 'aeroporto', 'ryanair', 'alitalia', 'aeroporti', 'coronavirus']
#
# Topic #57:
#
# ['luca', 'de', 'campania', 'coronavirus', 'zaia', 'ordinanza', 'vincenzo', 'governatore', 'presidente', 'gt']
#
# Topic #14:
#
# ['russia', 'putin', 'russo', 'vaccino', 'russi', 'sputnik', 'mosca', 'russa', 'primo', 'covid19']
#
# Topic #32:
#
# ['africa', 'africani', 'nigeria', 'egitto', 'primo', 'coronavirus', 'caso', 'sudafrica', 'variante', 'africano']
#
# Topic #77:
#
# ['lazio', 'casi', 'roma', 'nuovi', 'positivi', 'oggi', 'coronavirus', 'amato', 'contagi', 'decessi']
#
# Topic #102:
#
# ['germania', 'merkel', 'coronavirus', 'tedesco', 'berlino', 'tedeschi', 'primo', 'contagi', 'lockdown', 'focolaio']
#
# Topic #73:
#
# ['natale', 'ristoranti', 'bar', 'covid19', 'pasqua', 'ristorante', 'natale2020', 'dpcm', 'capodanno', 'lockdown']
#
# Topic #129:
#
# ['dale', 'bravo', 'cazzo', 'cosa', 'basta', 'cuomo', 'vergogna', 'raga', 'porca', 'que']
#
# Topic #139:
#
# ['fase', 'coronavirus', 'dpcm', 'maggio', 'conte', 'nuovo', 'cosa', 'fase2', 'regole', 'via']
#
# Topic #45:
#
# ['brasile', 'morti', 'brasiliana', 'mondo', 'variante', 'oltre', 'casi', 'coronavirus', 'usa', 'mila']
#
# Topic #35:
#
# ['scienza', 'scienziati', 'scientifico', 'scientifica', 'scientifiche', 'scienziato', 'scientifici', 'comitato', 'comunità', 'tecnico']
#
# Topic #27:
#
# ['app', 'immuni', 'tracciamento', 'privacy', 'scaricare', 'immuniapp', 'download', 'tracciare', 'funziona', 'contact']
#
# Topic #7:
#
# ['israele', 'israeliano', 'palestinesi', 'gaza', 'vaccino', 'israeliani', 'netanyahu', 'lockdown', 'covid19', 'palestina']
#
# Topic #76:
#
# ['emilia', 'romagna', 'nuovi', 'casi', 'aggiornamento', 'positivi', 'contagi', 'morti', 'coronavirus', 'reggio']
#
# Topic #24:
#
# ['f1', 'gp', 'motogp', 'ferrari', 'formula', 'lamborghini', 'valentino', 'hamilton', 'formula1', 'rossi']
#
# Topic #16:
#
# ['johnson', 'boris', 'amp', 'vaccino', 'borisjohnson', 'premier', 'johnsonandjohnson', 'coronavirus', 'regno', 'unito']
#
# Topic #148:
#
# ['nuovi', 'casi', 'contagi', 'calabria', 'coronavirus', 'sardegna', 'provincia', 'decesso', 'decessi', 'nessun']
#
# Topic #136:
#
# ['test', 'sierologici', 'rapidi', 'rapido', 'coronavirus', 'minuti', 'sierologico', 'via', 'tamponi', 'saliva']
#
# Topic #8:
#
# ['svezia', 'svedese', 'modello', 'lockdown', 'stoccolma', 'morti', 'strategia', 'norvegia', 'mortalità', 'covid19']
#
# Topic #103:
#
# ['germania', 'merkel', 'tedeschi', 'tedesco', 'tedesca', 'lockdown', 'covid19', 'berlino', 'angela', 'italia']
#
# Topic #70:
#
# ['lombardia', 'lombardi', 'regione', 'lombardo', 'lombarda', 'solo', 'sconvolsero', 'regioni', 'gallera', 'fatto']
#
# Topic #144:
#
# ['lombardia', 'nuovi', 'casi', 'morti', 'contagi', 'decessi', '24', 'milano', 'ore', 'coronavirus']
#
# Topic #101:
#
# ['francia', 'parigi', 'macron', 'francese', 'coronavirus', 'francesi', 'lockdown', 'coprifuoco', 'contagi', 'allerta']
#
# Topic #95:
#
# ['2020', '2021', 'anno', 'covid19', 'marzo', '2019', 'solo', 'febbraio', 'stato', '2022']
#
# Topic #1:
#
# ['sale', 'totale', 'paese', 'decessi', 'morti', 'mondo', 'nuovi', 'coronavirus', 'colpiti', 'incremento']
#
# Topic #80:
#
# ['migranti', 'immigrati', 'clandestini', 'immigrazione', 'covid19', 'italiani', 'lamorgese', 'portano', 'sbarchi', 'accoglienza']
#
# Topic #74:
#
# ['test', 'rapidi', 'sierologici', 'sierologico', 'covid19', 'covid', '19', 'rapido', 'pcr', 'tampone']
#
# Topic #30:
#
# ['migranti', 'immigrati', 'coronavirus', 'immigrazione', 'quarantena', 'salvini', 'clandestini', 'navi', 'governo', 'musumeci']
#
# Topic #25:
#
# ['berlusconi', 'silvio', 'positivo', 'zangrillo', 'raffaele', 'ricoverato', 'briatore', 'coronavirus', 'san', 'covid19']
#
# Topic #119:
#
# ['pandemia', 'cosa', 'durante', 'inizio', 'epidemia', 'quando', 'dopo', 'anno', 'solo', 'fatto']
#
# Topic #131:
#
# ['euro', 'milioni', 'miliardi', 'coronavirus', 'dona', 'emergenza', 'mln', 'mila', 'lavoro', 'imprese']
#
# Topic #141:
#
# ['puglia', 'casi', 'bat', 'bari', 'nuovi', 'barese', 'provincia', 'news24city', 'contagi', 'positivi']
#
# Topic #67:
#
# ['arancione', 'zona', 'gialla', 'rossa', 'arancioni', 'covid19', 'giallo', 'zone', 'rosso', 'gialle']
#
# Topic #117:
#
# ['virus', '19', 'covid19', 'covid', 'influenza', 'solo', 'hiv', 'stagionale', 'virologi', 'aids']
#
# Topic #147:
#
# ['toscana', 'nuovi', 'casi', 'decessi', 'guarigioni', 'decesso', 'coronavirus', 'nessun', 'aggiornamento', 'ricoveri']
#
# Topic #44:
#
# ['bolsonaro', 'brasile', 'presidente', 'positivo', 'jair', 'brasiliano', 'coronavirus', 'covid19', 'sintomi', 'morti']
#
# Topic #10:
#
# ['grecia', 'greco', 'torre', 'croazia', 'malta', 'spagna', 'rientra', 'coronavirus', 'guarigioni', 'casi']
#
# Topic #114:
#
# ['tweet', 'twitter', 'scritto', 'commenti', 'leggere', 'solo', 'fa', 'quando', 'account', 'profilo']
#
# Topic #59:
#
# ['anziani', 'giovani', 'pensione', 'pensionati', 'indispensabili', 'vecchi', 'pensioni', 'persone', 'produttivo', 'toti']
#
# Topic #100:
#
# ['francia', 'macron', 'francesi', 'francese', 'parigi', 'covid19', 'lockdown', 'emmanuel', 'france', 'positivo']
#
# Topic #18:
#
# ['ieri', 'pos', '12diagnosi', '11diagnosi', 'positivi', '16', '1ricoveri', 'casi', 'coronavirus', '11']
#
# Topic #134:
#
# ['regione', 'rossa', 'zona', 'musumeci', 'regioni', 'sicilia', 'coronavirus', 'regionale', 'zone', 'rosse']
#
# Topic #124:
#
# ['governo', 'italia', 'coronavirus', 'politica', 'italiani', 'matteosalvinimi', 'solo', 'politici', 'paese', 'fatto']
#
# Topic #62:
#
# ['gt', 'basilicata', 'coronavirus', 'matera', 'leggi', 'positivi', 'salernitanoleggi', 'emergenza', 'salernitano', 'ultim']
#
# Topic #0:
#
# ['pezzo', 'interessa', 'piacere', 'grazie', 'pomeriggio', 'buon', 'follow', 'prego', 'ricambiato', 'pezzi']
#
# Topic #87:
#
# ['palermo', 'coronavirus', 'turista', 'caso', 'orlando', 'bergamasca', 'sicilia', 'bergamo', 'primo', 'gds']
#
# Topic #120:
#
# ['giornalisti', 'giornalismo', 'giornalista', 'giornali', 'giornale', 'fake', 'media', 'stampa', 'news', 'notizie']
#
# Topic #23:
#
# ['giappone', 'tokyo', 'giapponese', 'emergenza', 'giapponesi', 'stato', 'coronavirus', 'olimpiadi', 'abe', 'mortalità']
#
# Topic #98:
#
# ['puntata', 'diretta', 'oggi', 'radio', '00', 'ore', 'onda', 'domani', 'podcast', 'canale']
#
# Topic #112:
#
# ['fascisti', 'fascista', 'fascismo', 'comunista', 'comunisti', 'nazisti', 'nazismo', 'comunismo', 'mussolini', 'antifascista']
#
# Topic #93:
#
# ['bambini', 'coronavirus', 'pediatri', 'pediatra', 'bimbi', 'figli', 'spiegato', 'adulti', 'piccoli', 'studio']
#
# Topic #137:
#
# ['vaccino', 'studio', 'coronavirus', 'vaccini', 'arcuri', 'anno', 'speranza', 'piano', 'entro', 'via']
#
# Topic #71:
#
# ['regioni', 'regione', 'governo', 'presidenti', 'regionali', 'regionale', 'responsabilità', 'tutte', 'presidente', 'cosa']
#
# Topic #15:
#
# ['iran', 'iraniano', 'morti', 'coronavirus', 'iraniani', 'iraniana', 'vittime', 'qom', 'sanzioni', 'casi']
#
# Topic #29:
#
# ['terrorismo', 'mediatico', 'terroristi', 'psicologico', 'covid19', 'basta', 'terrorista', 'bomba', 'media', 'solo']
#
# Topic #26:
#
# ['apple', 'iphone', 'google', 'ios', 'store', 'app', 'tracciamento', 'coronavirus', '19', 'covid']
#
# Topic #66:
#
# ['arancione', 'zona', 'regioni', 'arancioni', 'gialla', 'rossa', 'coronavirus', 'toscana', 'sicilia', 'rosse']
#
# Topic #20:
#
# ['gates', 'bill', 'vaccino', 'tesla', 'musk', 'elon', 'billgates', 'coronavirus', 'profezia', 'pandemia']
#
# Topic #17:
#
# ['playhitmusic', 'coronavirus', 'bollettino', 'oggi', 'lombardia', 'lazio', 'cosa', 'italia', 'emergenza', 'dati']
#
# Topic #36:
#
# ['sarscov2', 'fakenews', 'stato', 'detto', 'creato', 'farci', 'ideato', 'sviluppato', 'lobby', 'complotto']
#
# Topic #63:
#
# ['2020', 'guglionesi', '19', 'aggiornamento', '2021', 'covid', 'pietroburgo', 'comune', 'emergenza', 'san']
#
# Topic #22:
#
# ['corea', 'sud', 'kim', 'nord', 'jong', 'seul', 'coronavirus', 'casi', 'korea', 'contagi']
#
# Topic #142:
#
# ['salvini', 'conte', 'matteo', 'governo', 'coronavirus', 'lega', 'meloni', 'sciacallo', 'mattarella', 'leader']
#
# Topic #50:
#
# ['mappa', 'italia', 'reale', 'contagio', 'contagi', 'coronavirus', 'tempo', 'interattiva', 'mappe', 'aggiornata']
#
# Topic #13:
#
# ['età', 'media', 'anni', 'toscana', 'nuovi', 'decessi', 'casi', '44', '45', '43']
#
# Topic #111:
#
# ['conte', 'fa', 'cosa', 'casalino', 'draghi', 'fatto', 'linkiesta', 'ora', 'stato', 'pd']
#
# Topic #109:
#
# ['smartworking', 'smart', 'working', 'lavoro', 'covid19', 'emergenza', 'lavorare', 'dipendenti', 'lavoratori', 'aziende']
#
# Topic #53:
#
# ['ronaldo', 'cristiano', 'messi', 'juventus', 'positivo', 'cr7', 'portoghese', 'juve', 'cristianoronaldo', 'portogallo']
#
# Topic #92:
#
# ['treni', 'treno', 'milano', 'stazione', 'fuga', 'coronavirus', 'trenitalia', 'passeggeri', 'assalto', 'sud']
#
# Topic #115:
#
# ['pandemia', '19', 'covid', 'covid19', 'epidemia', 'effetti', 'impatto', 'durante', 'causa', 'globale']
#
# Topic #48:
#
# ['coronaviruscases', 'contagiati', 'notizie', 'ultime', 'oggi', 'morti', 'casi', 'coronavirus', 'san', 'pietro']
#
# Topic #46:
#
# ['fakenews', 'stato', 'detto', 'creato', 'complotto', 'farci', 'ideato', 'bufala', 'sviluppato', 'video']
#
# Topic #146:
#
# ['liguria', 'positivi', 'nuovi', 'savonese', 'coronavirus', 'casi', 'tamponi', 'ospedalizzati', 'oggi', 'provincia']
#
# Topic #12:
#
# ['pizza', 'pizzeria', 'video', 'francese', 'pizze', 'canal', 'francia', 'mandolino', 'coronavirus', 'hut']
#
# Topic #52:
#
# ['tennis', 'djokovic', 'novak', 'positivo', 'torneo', 'tennista', 'adria', 'dimitrov', 'fognini', 'federer']
#
# Topic #3:
#
# ['radioradiotv', 'magazine', 'impresa', 'donna', 'dicono', 'topwomen', 'cina', 'baltimore', 'savona', 'spezia']
#
# Topic #19:
#
# ['diamond', 'princess', 'nave', 'passeggeri', 'italiani', 'italiano', 'bordo', 'coronavirus', 'volo', 'crociera']
#
# Topic #138:
#
# ['sindaco', 'coronavirus', 'polizia', 'torino', 'controlli', 'carabinieri', 'via', 'bari', 'città', 'strade']
#
# Topic #96:
#
# ['napoli', 'coronavirus', 'cotugno', 'lungomare', 'contagiato', 'emergenza', 'via', 'cardarelli', 'ospedale', 'mare']
#
# Topic #4:
#
# ['compilare', 'anonimo', 'questionario', 'condividere', 'scientifica', 'prego', 'sostenibilità', 'ricerca', 'ita', 'arrangiare']
#
# Topic #2:
#
# ['ncov', 'polmonite', '2019', 'informazioni', 'aggiornamenti', 'ultimo', 'epidemia', '20', 'aggiornamento', '07']
#
# Topic #105:
#
# ['farmaci', 'farmaco', 'farmaceutiche', 'dose', 'case', 'pfizer', 'farmacia', 'idrossiclorochina', 'pharma', 'farmaceutica']
#
# Topic #5:
#
# ['2020positivi', '11', '1guariti', '12', 'positividecessi', '10', 'record', 'malvezzi', '2guariti', '0guariti']
#
# Topic #82:
#
# ['notizia', 'notizie', 'buona', 'bella', 'buone', 'belle', 'news', 'ottima', 'noticia', 'finalmente']
#
# Topic #68:
#
# ['sars', 'cov', 'virus', 'sarscov2', 'cov2', 'nuovo', 'studio', '2020', 'variante', 'coronavirus']
#
# Topic #104:
#
# ['m5s', 'pd', 'coronavirus', 'lega', 'emergenza', 'attacca', 'salvini', 'aula', 'mes', 'bagarre']
#
# Topic #94:
#
# ['giovani', 'coronavirus', 'adolescenti', 'allarme', 'appello', 'attenzione', 'oms', 'movida', 'draghi', 'futuro']
#
# Topic #126:
#
# ['salvini', 'meloni', 'quando', 'renzi', 'lega', 'cosa', 'sa', 'elettori', 'opposizione', 'governo']
#
# Topic #31:
#
# ['scuola', 'scuole', 'positivi', 'studenti', 'positivo', 'classe', 'studente', 'positiva', 'quarantena', 'liceo']
#
# Topic #79:
#
# ['positiva', 'bimbo', 'bimba', 'positivo', 'bambino', 'anni', 'donna', 'partorisce', 'bambina', 'mamma']
#
# Topic #54:
#
# ['napoli', 'napoletani', 'covid19', 'città', 'napolijuve', 'sempre', 'solo', 'fatto', 'demagistris', 'cosa']
#
# Topic #133:
#
# ['ristoranti', 'bar', 'chiusi', 'parrucchieri', 'coronavirus', 'negozi', 'pub', '18', 'palestre', 'riaprono']
#
# Topic #150:
#
# ['morti', 'bollettino', 'positivi', 'italia', 'positività', 'tasso', 'casi', 'oggi', 'coronavirus', 'nuovi']
#
# Topic #123:
#
# ['fase', 'fase2', 'due', 'covid19', 'maggio', 'fase1', 'cosa', 'conte', 'prima', 'inizia']
#
# Topic #41:
#
# ['lazio', 'covid19', 'regione', 'zingaretti', 'lotito', 'tar', 'oggi', 'nzingaretti', 'forzalazio', 'immobile']
#
# Topic #140:
#
# ['italia', 'coronavirus', 'emergenza', 'stato', 'due', 'oms', 'primi', 'casi', 'italiano', 'italy']
#
# Topic #28:
#
# ['razzismo', 'razzisti', 'razzista', 'coronavirus', 'paura', 'virus', 'odio', 'solo', 'sardine', 'italia']
#
# Topic #122:
#
# ['24', 'casi', 'ultime', 'morti', 'ore', 'nuovi', 'italia', 'stati', 'covid19', 'tamponi']
#
# Topic #85:
#
# ['india', 'milioni', 'casi', 'record', 'mondo', 'contagi', 'supera', 'coronavirus', 'oltre', 'giorno']
#
# Topic #72:
#
# ['mascherina', 'mascherine', 'maschera', 'coronavirus', 'maschere', 'carnevale', 'indossare', 'usare', 'comprare', 'proteggersi']
#
# Topic #90:
#
# ['bollettino', 'dati', 'oggi', 'aggiornati', 'coronavirus', 'marzo', 'aprile', 'settembre', 'dicembre', 'ottobre']
#
# Topic #135:
#
# ['lombardia', 'positivi', 'nuovi', 'decessi', 'bergamo', 'casi', 'tamponi', 'coronavirus', 'milano', 'radiolombardia']
#
# Topic #84:
#
# ['india', 'covid19', 'modi', 'narendra', 'minister', 'indiani', 'indiano', 'delhi', 'pakistan', 'covid']
#
# Topic #116:
#
# ['vaccino', 'sperimentazione', 'test', 'uomo', 'via', 'spallanzani', 'primi', 'coronavirus', 'volontari', 'italiano']
#
# Topic #37:
#
# ['fakenews', 'detto', 'covid19', 'stato', 'lobby', 'farci', 'bufala', 'complotto', 'creato', 'strategia']
#
# Topic #81:
#
# ['smart', 'working', 'digitale', 'smartworking', 'coronavirus', 'lavoro', 'emergenza', 'aziende', 'via', 'dopo']
#
# Topic #89:
#
# ['2020', 'bollettino', 'oggi', 'maggio', 'coronavirus', 'marzo', 'dati', 'italia', 'santena', 'agosto']
#
# Topic #49:
#
# ['laboratorio', 'wuhan', 'virus', 'nato', 'origine', 'creato', 'usa', 'oms', 'indagano', 'coronavirus']
#
# Topic #6:
#
# ['molise', 'molisenews24', 'giorno', 'dati', '2020', 'novembre', 'ottobre', 'coronavirus', 'agosto', 'dicembre']
#
# Topic #47:
#
# ['musei', 'museo', 'biblioteche', 'chiusi', 'cultura', 'riaprono', 'coronavirus', 'mostre', 'cinema', 'riapertura']
#
# Topic #39:
#
# ['piemonte', 'regionepiemonte', 'alberto_cirio', 'covid19', 'cirio', 'piemonteinforma', 'torino', 'piemontesi', 'rossa', 'regione']
#
# Topic #99:
#
# ['francia', 'oltre', 'contagi', 'casi', '24', 'spagna', 'ore', 'record', 'mila', 'coronavirus']
#
# Topic #58:
#
# ['positivi', 'tamponi', 'nuovi', 'effettuati', 'ieri', 'percentuale', 'casi', 'rapporto', '24', 'oggi']
#
# Topic #88:
#
# ['abruzzo', 'dati', 'giorno', 'aggiornamento', '2020', 'basilicata', 'notizieabruzzo', '2021', 'emergenza', 'novembre']
#
# Topic #9:
#
# ['messina', 'articolo', 'nuovo', 'pubblicato', 'stato', 'tempo', 'stretto', 'sicilia', 'ricoveri', 'coronavirus']
#
# Topic #42:
#
# ['nave', 'crociera', 'civitavecchia', 'sospetti', 'navi', 'due', 'bordo', 'cayman', 'giamaica', 'msc']
#
# Topic #110:
#
# ['digitale', 'digitalizzazione', 'digital', 'digitali', 'covid19', 'opportunità', 'emergenza', 'innovazione', 'accelerato', 'tecnologie']
#
# Topic #83:
#
# ['migranti', 'positivi', 'lampedusa', 'sbarcati', 'immigrati', 'coronavirus', 'nave', 'sbarco', '28', 'pozzallo']
#
# Topic #69:
#
# ['milano', 'milanononsiferma', 'navigli', 'foto', 'milanese', 'gente', 'fermarsi', 'milanesi', 'beppesala', 'nulla']
#
# Topic #106:
#
# ['idrossiclorochina', 'farmaco', '19', 'covid', 'covid19', 'uso', 'mortalità', 'trattamento', 'riduce', 'aifa']
#
# Topic #51:
#
# ['podcast', 'spreaker', 'nuovo', 'fantasticaradio', 'fm', '89', 'fantastica', 'diretta', 'catania', 'covid']
#
# Topic #91:
#
# ['emergenza', 'stato', 'finita', 'terminata', 'pensare', 'giusto', 'esperienza', 'vera', 'fase', 'prolungamento']
#
# Topic #113:
#
# ['forze', 'ordine', 'manifestazioni', 'polizia', 'protestare', 'protesta', 'poliziotti', 'piazza', 'proteste', 'carabinieri']

# %%
import matplotlib.pyplot as plt
from datetime import datetime


text_raw_df['dates'] =  text_raw_df['publication_date'].apply(lambda x:  datetime.fromtimestamp(x))
text_raw_df['Topic'] = cluster.labels_

i = 0
for num_topic in topic_sizes['Topic']:
    ax = text_raw_df.groupby([text_raw_df['Topic'], text_raw_df['dates'].dt.year, text_raw_df['dates'].dt.month]).count()['id'][num_topic].plot(kind="bar") #Imprime el topic cero
    ax.grid(b=True, axis='both')
    #print(type(ax))
    ax.set_title('Distribución del Topic ' + str(num_topic) + ' en los documentos en inglés')
    ax.set_xlabel('Mes y año de los tweets')
    ax.set_ylabel('Número de tweets del topic')
    plt.show()
    i = i+1
    if (i>10):
        break

# %% [markdown]
# # Italian with different params on HDBScan

# %%
import hdbscan
cluster = hdbscan.HDBSCAN(min_cluster_size=70,
                          metric='euclidean',
                          cluster_selection_method='eom',
                          min_samples=400).fit(umap_embeddings)

# %% [markdown]
# ### Visualisación de los clusters

# %%
import matplotlib.pyplot as plt

# Prepare data
umap_data = umap.UMAP(n_neighbors=30, n_components=2, min_dist=0.0, metric='cosine').fit_transform(umap_embeddings)
result = pd.DataFrame(umap_data, columns=['x', 'y'])
result['labels'] = cluster.labels_

# Visualize clusters
fig, ax = plt.subplots(figsize=(20, 10))
outliers = result.loc[result.labels == -1, :]
clustered = result.loc[result.labels != -1, :]
plt.scatter(outliers.x, outliers.y, color='#BDBDBD', s=0.05)
plt.scatter(clustered.x, clustered.y, c=clustered.labels, s=0.05, cmap='hsv_r')
plt.colorbar()

# %% [markdown]
# ### c-TF-IDF

# %%
docs_df = pd.DataFrame(raw_texts, columns=["Doc"])
docs_df['Topic'] = cluster.labels_
docs_df['Doc_ID'] = range(len(docs_df))
docs_per_topic = docs_df.groupby(['Topic'], as_index = False).agg({'Doc': ' '.join})

# %%
def c_tf_idf(documents, m, ngram_range=(1, 1)):
    count = CountVectorizer(ngram_range=ngram_range, stop_words=get_stop_words('italian')).fit(documents)
    t = count.transform(documents).toarray()
    w = t.sum(axis=1)
    tf = np.divide(t.T, w)
    sum_t = t.sum(axis=0)
    idf = np.log(np.divide(m, sum_t)).reshape(-1, 1)
    tf_idf = np.multiply(tf, idf)

    return tf_idf, count

tf_idf, count = c_tf_idf(docs_per_topic.Doc.values, m=len(raw_texts))

# %%
def extract_top_n_words_per_topic(tf_idf, count, docs_per_topic, n=20):
    words = count.get_feature_names()
    labels = list(docs_per_topic.Topic)
    tf_idf_transposed = tf_idf.T
    indices = tf_idf_transposed.argsort()[:, -n:]
    top_n_words = {label: [(words[j], tf_idf_transposed[i][j]) for j in indices[i]][::-1] for i, label in enumerate(labels)}
    return top_n_words

def extract_topic_sizes(df):
    topic_sizes = (df.groupby(['Topic'])
                     .Doc
                     .count()
                     .reset_index()
                     .rename({"Topic": "Topic", "Doc": "Size"}, axis='columns')
                     .sort_values("Size", ascending=False))
    return topic_sizes

top_n_words = extract_top_n_words_per_topic(tf_idf, count, docs_per_topic, n=20)
topic_sizes = extract_topic_sizes(docs_df);
topic_sizes.head(10)
# Out:
#    Topic    Size
# 4      3  808009
# 0     -1    4149
# 2      1    1452
# 1      0     697
# 3      2     178

# %%
len(topic_sizes)
# Out:
# 5

# %%
print(len(topic_sizes['Topic']))
for topic in topic_sizes['Topic']:
  if topic == -1:
    continue
  print('Topic #' + str(topic) +":"+ '\n')
  print(str([t[0] for t in top_n_words[topic][:10]]) + '\n')
# Out:
# 5
# Topic #3:
#
# ['coronavirus', 'covid19', 'covid', 'casi', '19', 'italia', 'nuovi', 'positivi', 'contagi', 'oggi']
#
# Topic #1:
#
# ['sale', 'totale', 'paese', 'decessi', 'morti', 'mondo', 'nuovi', 'ncov', 'polmonite', '2019']
#
# Topic #0:
#
# ['pezzo', 'interessa', 'piacere', 'grazie', 'pomeriggio', 'buon', 'follow', 'prego', 'ricambiato', 'pezzi']
#
# Topic #2:
#
# ['radioradiotv', 'dicono', 'savona', 'spezia', 'imperia', 'genova', 'coronavirus', 'covid19', '091', '62']

# %%
import matplotlib.pyplot as plt
from datetime import datetime


text_raw_df['dates'] =  text_raw_df['publication_date'].apply(lambda x:  datetime.fromtimestamp(x))
text_raw_df['Topic'] = cluster.labels_
text_raw_df


for num_topic in topic_sizes['Topic']:
    ax = text_raw_df.groupby([text_raw_df['Topic'], text_raw_df['dates'].dt.year, text_raw_df['dates'].dt.month]).count()['id'][num_topic].plot(kind="bar") #Imprime el topic cero
    ax.grid(b=True, axis='both')
    #print(type(ax))
    ax.set_title('Distribución del Topic ' + str(num_topic) + ' en los documentos en inglés')
    ax.set_xlabel('Mes y año de los tweets')
    ax.set_ylabel('Número de tweets del topic')
    plt.show()
