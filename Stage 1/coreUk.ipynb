# %% [markdown]
# Import modules

# %%
import requests

# %% [markdown]
# Defining endpoints

# %%
url = 'https://core.ac.uk:443/api-v2/search'
apiKey = 'uLFsR2TgKOzkeX0iN5vWSopAVPrjJM9l'
path = f'{url}?apiKey={apiKey}'
print('Path', path)
# Out:
# Path https://core.ac.uk:443/api-v2/search?apiKey=uLFsR2TgKOzkeX0iN5vWSopAVPrjJM9l

# %% [markdown]
# Querying

# %%
body = [    
    {
        "query": "coronavirus",
        "page": 1,
        "pageSize": 10 
    }
    # ,
    # {
    #     "query": "covid 19",
    #     "page": 1,
    #     "pageSize": 1
    # }
    ]

print(body)

r = requests.post(path, json=body)
print(r.text)
# Out:
# Id":0,"name":"CiteSeerX","uri":null,"urlHomepage":null,"urlOaipmh":null,"uriJournals":null,"physicalName":"noname","source":null,"software":null,"metadataFormat":null,"description":null,"journal":null,"roarId":0,"pdfStatus":null,"nrUpdates":0,"disabled":false,"lastUpdateTime":null,"repositoryLocation":null}],"repositoryDocument":{"pdfStatus":0,"textStatus":0,"metadataAdded":1509376260000,"metadataUpdated":1529493682000,"timestamp":1472079600000,"depositedDate":1472079600000,"indexed":0,"deletedStatus":"0","pdfSize":0,"tdmOnly":false,"pdfOrigin":"ftp:\/\/ftp.ncbi.nlm.nih.gov\/pub\/pmc\/e3\/a5\/12900_2015_Article_35.PMC4411765.pdf"},"similarities":null,"subjects":["text"],"title":"RESEARCH ARTICLE Open Access","topics":[],"types":[],"urls":["ftp:\/\/ftp.ncbi.nlm.nih.gov\/pub\/pmc\/e3\/a5\/12900_2015_Article_35.PMC4411765.pdf","ftp:\/\/ftp.ncbi.nlm.nih.gov\/pub\/pmc\/e3\/a5\/12900_2015_Article_35.PMC4411765.pdf","http:\/\/citeseerx.ist.psu.edu\/viewdoc\/summary?doi=10.1.1.809.1633"],"year":2016,"doi":null,"oai":"oai:CiteSeerX.psu:10.1.1.809.1633","downloadUrl":"","pdfHashValue":null,"documentType":null,"documentTypeConfidence":null,"citationCount":null,"estimatedCitationCount":null,"acceptedDate":null,"depositedDate":1472079600000,"publishedDate":null,"issn":null,"crossrefDocument":null,"magDocument":null}},{"_index":"articles_2019_06_05","_type":"article","_id":"102080406","_score":19.478401,"_source":{"id":"102080406","authors":["Coronavirus Nonstructural Protein"],"citations":[],"contributors":["The Pennsylvania State University CiteSeerX Archives"],"datePublished":"2007","deleted":"ALLOWED","description":"This article cites 74 articles, 51 of which can be accessed fre","fullText":null,"fullTextIdentifier":"http:\/\/jvi.asm.org\/content\/81\/22\/12323.full.pdf","identifiers":["oai:CiteSeerX.psu:10.1.1.596.8651",null],"journals":null,"language":null,"duplicateId":null,"publisher":null,"rawRecordXml":"\u003Crecord\u003E\u003Cheader\u003E\u003Cidentifier\u003E\n    \n      \n        oai:CiteSeerX.psu:10.1.1.596.8651\u003C\/identifier\u003E\u003Cdatestamp\u003E\n        2015-07-06\u003C\/datestamp\u003E\n      \u003C\/header\u003E\u003Cmetadata\u003E\u003Coai_dc:dc xmlns:oai_dc=\u0022http:\/\/www.openarchives.org\/OAI\/2.0\/oai_dc\/\u0022 xmlns:dc=\u0022http:\/\/purl.org\/dc\/elements\/1.1\/\u0022 xsi:schemaLocation=\u0022http:\/\/www.openarchives.org\/OAI\/2.0\/oai_dc\/ http:\/\/www.openarchives.org\/OAI\/2.0\/oai_dc.xsd\u0022 \u003E\u003Cdc:title\u003E\n      \n        \n          CONTENT ALERTS\u003C\/dc:title\u003E\u003Cdc:creator\u003E\n          Coronavirus Nonstructural Protein\u003C\/dc:creator\u003E\u003Cdc:description\u003E\n          This article cites 74 articles, 51 of which can be accessed free\u003C\/dc:description\u003E\u003Cdc:contributor\u003E\n          The Pennsylvania State University CiteSeerX Archives\u003C\/dc:contributor\u003E\u003Cdc:publisher\u003E\n          \u003C\/dc:publisher\u003E\u003Cdc:date\u003E\n          2015-07-06\u003C\/dc:date\u003E\u003Cdc:date\u003E\n          2015-07-06\u003C\/dc:date\u003E\u003Cdc:date\u003E\n          2007\u003C\/dc:date\u003E\u003Cdc:format\u003E\n          application\/pdf\u003C\/dc:format\u003E\u003Cdc:type\u003E\n          text\u003C\/dc:type\u003E\u003Cdc:identifier\u003E\n          http:\/\/citeseerx.ist.psu.edu\/viewdoc\/summary?doi=10.1.1.596.8651\u003C\/dc:identifier\u003E\u003Cdc:source\u003E\n          http:\/\/jvi.asm.org\/content\/81\/22\/12323.full.pdf\u003C\/dc:source\u003E\u003Cdc:language\u003E\n          en\u003C\/dc:language\u003E\u003Cdc:rights\u003E\n          Metadata may be used without restrictions as long as the oai identifier remains attached to it.\u003C\/dc:rights\u003E\n        \u003C\/oai_dc:dc\u003E\n      \u003C\/metadata\u003E\n    \u003C\/record\u003E","relations":[],"repositories":[{"id":"145","openDoarId":0,"name":"CiteSeerX","uri":null,"urlHomepage":null,"urlOaipmh":null,"uriJournals":null,"physicalName":"noname","source":null,"soft ...

# %%
def getKeys(d):
    return print(list(d.keys()))

# print(r.json()[1]['data'][0]['_source']['description'])
# print(r.json()[1])
getKeys(r.json()[0]['data'][0]['_source'])
print(type(r.json()[0]['data'][0]['_source']))
# Out:
# ['id', 'authors', 'citations', 'contributors', 'datePublished', 'deleted', 'description', 'fullText', 'fullTextIdentifier', 'identifiers', 'journals', 'language', 'duplicateId', 'publisher', 'rawRecordXml', 'relations', 'repositories', 'repositoryDocument', 'similarities', 'subjects', 'title', 'topics', 'types', 'urls', 'year', 'doi', 'oai', 'downloadUrl', 'pdfHashValue', 'documentType', 'documentTypeConfidence', 'citationCount', 'estimatedCitationCount', 'acceptedDate', 'depositedDate', 'publishedDate', 'issn', 'crossrefDocument', 'magDocument']
# <class 'dict'>

# %% [markdown]
# ***
# ```
# r.json()[0]['data'])
# r.json()[0]['data'][0]['_source'])
# r.json()[0]['data'][0]['_source']['description'])
# [ For each query one response object
#     {
#         "status": string.
#         "totalHits": #,
#         "data": [ List of retrieved resources
#         {
#             "_index": ,
#             "_type": ["article" or "journal" or "repositories"],
#             "_id": ,
#             "_score":,
#             "source": { key:value con las siguientes keys
#             'id', 'authors', 'citations', 'contributors', 'datePublished', 'deleted', 'description',
#             'fullText', 'fullTextIdentifier', 'identifiers', 'journals', 'language', 'duplicateId',
#             'publisher', 'rawRecordXml', 'relations', 'repositories', 'repositoryDocument', 'similarities',
#              'subjects', 'title', 'topics', 'types', 'urls', 'year', 'doi', 'oai', 'downloadUrl', 'pdfHashValue',
#               'documentType', 'documentTypeConfidence', 'citationCount', 'estimatedCitationCount', 'acceptedDate',
#               'depositedDate', 'publishedDate', 'issn', 'crossrefDocument', 'magDocument'
#             }
#         },
#         {..}, {..}, ..
#         ]
#     },
#
#     {
#
#     },
#     .
#     .
#     .
# ]
# ```

# %%
import json
print(json.dumps(r.json(), indent=2))
# Out:
#           "language": null,
#           "duplicateId": null,
#           "publisher": null,
#           "rawRecordXml": "<record><header><identifier>\n    \n      \n        oai:CiteSeerX.psu:10.1.1.596.8651</identifier><datestamp>\n        2015-07-06</datestamp>\n      </header><metadata><oai_dc:dc xmlns:oai_dc=\"http://www.openarchives.org/OAI/2.0/oai_dc/\" xmlns:dc=\"http://purl.org/dc/elements/1.1/\" xsi:schemaLocation=\"http://www.openarchives.org/OAI/2.0/oai_dc/ http://www.openarchives.org/OAI/2.0/oai_dc.xsd\" ><dc:title>\n      \n        \n          CONTENT ALERTS</dc:title><dc:creator>\n          Coronavirus Nonstructural Protein</dc:creator><dc:description>\n          This article cites 74 articles, 51 of which can be accessed free</dc:description><dc:contributor>\n          The Pennsylvania State University CiteSeerX Archives</dc:contributor><dc:publisher>\n          </dc:publisher><dc:date>\n          2015-07-06</dc:date><dc:date>\n          2015-07-06</dc:date><dc:date>\n          2007</dc:date><dc:format>\n          application/pdf</dc:format><dc:type>\n          text</dc:type><dc:identifier>\n          http://citeseerx.ist.psu.edu/viewdoc/summary?doi=10.1.1.596.8651</dc:identifier><dc:source>\n          http://jvi.asm.org/content/81/22/12323.full.pdf</dc:source><dc:language>\n          en</dc:language><dc:rights>\n          Metadata may be used without restrictions as long as the oai identifier remains attached to it.</dc:rights>\n        </oai_dc:dc>\n      </metadata>\n    </record>",
#           "relations": [],
#           "repositories": [
#             {
#               "id": "145",
#               "openDoarId": 0,
#               "name": "CiteSeerX",
#               "uri": null,
#               "urlHomepage": null,
#               "urlOaipmh": null,
#               "uriJournals": null,
#               "physicalName": "noname",
#               "source": null,
#               "software": null,
#               "metadataFormat": null,
#               "description": null,
#               "journal": null,
#               "roarId": 0,
#               "pdfStatus": null,
#               "nrUpdates": 0,
#               "disabled": false,
#               "lastUpdateTime": null,
#               "repositoryLocation": null
#             }
#           ],
#           "repositoryDocument": {
#             "pdfStatus": 0,
#             "textStatus": 0,
#             "metadataAdded": 1509251227000,
#             "metadataUpdated": 1529468919000,
#             "timestamp": 1436137200000,
#             "depositedDate": 1436137200000,
#             "indexed": 0,
#             "deletedStatus": "0",
#             "pdfSize": 0,
#             "tdmOnly": false,
#             "pdfOrigin": "http://jvi.asm.org/content/81/22/12323.full.pdf"
#           },
#           "similarities": null,
#           "subjects": [
#             "text"
#           ],
#           "title": "CONTENT ALERTS",
#           "topics": [],
#           "types": [],
#           "urls": [
#             "http://jvi.asm.org/content/81/22/12323.full.pdf",
#             "http://jvi.asm.org/content/81/22/12323.full.pdf",
#             "http://citeseerx.ist.psu.edu/viewdoc/summary?doi=10.1.1.596.8651"
#           ],
#           "year": 2007,
#           "doi": null,
#           "oai": "oai:CiteSeerX.psu:10.1.1.596.8651",
#           "downloadUrl": "",
#           "pdfHashValue": null,
#           "documentType": null,
#           "documentTypeConfidence": null,
#           "citationCount": null,
#           "estimatedCitationCount": null,
#           "acceptedDate": null,
#           "depositedDate": 1436137200000,
#           "publishedDate": null,
#           "issn": null,
#           "crossrefDocument": null,
#           "magDocument": null
#         }
#       },
#       {
#         "_index": "articles_2019_06_05",
#         "_type": "article",
#         "_id": "108920394",
#         "_score": 19.377394,
#         "_source": {
#           "id": "108920394",
#           "authors": [
#             "Coronavirus Strain",
#             "Hku Variant"
#           ],
#           "citations": [],
#           "contributors": [
#             "The Pennsylvania State University CiteSeerX Archives"
#           ],
#           "datePublished": "2016-10-04",
#           "deleted": "ALLOWED",
#           "description": "ABSTRACT Cross-species transmission of zoonotic coronaviruses (CoVs) can result in pandemic disease outbreaks. Middle East respiratory syndrome CoV (MERS-CoV), identified in 2012, has caused 182 cases to date, with ~43%mortality, and no small ani-mal model has been reported. MERS-CoV and Pipistrellus bat coronavirus (BtCoV) strain HKU5 of Betacoronavirus (-CoV) subgroup 2c share&gt;65 % identity at the amino acid level in several regions, including nonstructural protein 5 (nsp5) and the nucleocapsid (N) protein, which are significant drug and vaccine targets. BtCoV HKU5 has been described in silico but has not been shown to replicate in culture, thus hampering drug and vaccine studies against subgroup 2c -CoVs. We report the syn-thetic reconstruction and testing of BtCoVHKU5 containing the severe acute respiratory syndrome (SARS)-CoV spike (S) glyco-protein ectodomain (BtCoVHKU5-SE). This virus replicates efficiently in cell culture and in young and agedmice, where the virus targets airway and alveolar epithelial cells. Unlike some subgroup 2b SARS-CoV vaccines that elicit a strong eosinophilia following challenge, we demonstrate that BtCoVHKU5 andMERS-CoVN-expressing Venezuelan equine encephalitis virus rep-licon particle (VRP) vaccines do not cause extensive eosinophilia following BtCoVHKU5-SE challenge. Passage of BtCoV HKU5-SE in youngmice resulted in enhanced virulence, causing 20%weight loss, diffuse alveolar damage, and hyaline mem",
#           "fullText": null,
#           "fullTextIdentifier": "http://mbio.asm.org/content/5/2/e00047-14.full.pdf",
#           "identifiers": [
#             "oai:CiteSeerX.psu:10.1.1.952.425",
#             null
#           ],
#           "journals": null,
#           "language": null,
#           "duplicateId": null,
#           "publisher": null,
#           "rawRecordXml": "<record><header><identifier>\n    \n      \n        oai:CiteSeerX.psu:10.1.1.952.425</identifier><datestamp>\n        2016-10-04</datestamp>\n      </header><metadata><oai_dc:dc xmlns:oai_dc=\"http://www.openarchives.org/OAI/2.0/oai_dc/\" xmlns:dc=\"http://purl.org/dc/elements/1.1/\" xsi:schemaLocation=\"http://www.openarchives.org/OAI/2.0/oai_dc/ http://www.openarchives.org/OAI/2.0/oai_dc.xsd\" ><dc:title>\n      \n        \n          A Mouse Model for Betacoronavirus Subgroup 2c Using a Bat</dc:title><dc:creator>\n          Coronavirus Strain</dc:creator><dc:creator>\n          Hku Variant</dc:creator><dc:description>\n          ABSTRACT Cross-species transmission of zoonotic coronaviruses (CoVs) can result in pandemic disease outbreaks. Middle East respiratory syndrome CoV (MERS-CoV), identified in 2012, has caused 182 cases to date, with ~43%mortality, and no small ani-mal model has been reported. MERS-CoV and Pipistrellus bat coronavirus (BtCoV) strain HKU5 of Betacoronavirus (-CoV) subgroup 2c share&gt;65 % identity at the amino acid level in several regions, including nonstructural protein 5 (nsp5) and the nucleocapsid (N) protein, which are significant drug and vaccine targets. BtCoV HKU5 has been described in silico but has not been shown to replicate in culture, thus hampering drug and vaccine studies against subgroup 2c -CoVs. We report the syn-thetic reconstruction and testing of BtCoVHKU5 containing the severe acute respiratory syndrome (SARS)-CoV spike (S) glyco-protein ectodomain (BtCoVHKU5-SE). This virus replicates efficiently in cell culture and in young and agedmice, where the virus targets airway and alveolar epithelial cells. Unlike some subgroup 2b SARS-CoV vaccines that elicit a strong eosinophilia following challenge, we demonstrate that BtCoVHKU5 andMERS-CoVN-expressing Venezuelan equine encephalitis virus rep-licon particle (VRP) vaccines do not cause extensive eosinophilia following BtCoVHKU5-SE challenge. Passage of BtCoV HKU5-SE in youngmice resulted in enhanced virulence, causing 20%weight loss, diffuse alveolar damage, and hyaline mem-</dc:description><dc:contributor>\n          The Pennsylvania State University CiteSeerX Archives</dc:contributor><dc:publisher>\n          </dc:publisher><dc:date>\n          2016-10-04</dc:date><dc:date>\n          2016-10-04</dc:date><dc:format>\n          application/pdf</dc:format><dc:type>\n          text</dc:type><dc:identifier>\n          http://citeseerx.ist.psu.edu/viewdoc/summary?doi=10.1.1.952.425</dc:identifier><dc:source>\n          http://mbio.asm.org/content/5/2/e00047-14.full.pdf</dc:source><dc:language>\n          en</dc:language><dc:rights>\n          Metadata may be used without restrictions as long as the oai identifier remains attached to it.</dc:rights>\n        </oai_dc:dc>\n      </metadata>\n    </record>",
#           "relations": [],
#           "repositories": [
#             {
#               "id": "145",
#               "openDoarId": 0,
#               "name": "CiteSeerX",
#               "uri": null,
#               "urlHomepage": null,
#               "urlOaipmh": null,
#               "uriJournals": null,
#               "physicalName": "noname",
#               "source": null,
#               "software": null,
#               "metadataFormat": null,
#               "description": null,
#               "journal": null,
#               "roarId": 0,
#               "pdfStatus": null,
#               "nrUpdates": 0,
#               "disabled": false,
#               "lastUpdateTime": null,
#               "repositoryLocation": null
#             }
#           ],
#           "repositoryDocument": {
#             "pdfStatus": 0,
#             "textStatus": 0,
#             "metadataAdded": 1509572284000,
#             "metadataUpdated": 1529516879000,
#             "timestamp": 1475535600000,
#             "depositedDate": 1475535600000,
#             "indexed": 0,
#             "deletedStatus": "0",
#             "pdfSize": 0,
#             "tdmOnly": false,
#             "pdfOrigin": "http://mbio.asm.org/content/5/2/e00047-14.full.pdf"
#           },
#           "similarities": null,
#           "subjects": [
#             "text"
#           ],
#           "title": "A Mouse Model for Betacoronavirus Subgroup 2c Using a Bat",
#           "topics": [],
#           "types": [],
#           "urls": [
#             "http://mbio.asm.org/content/5/2/e00047-14.full.pdf",
#             "http://mbio.asm.org/content/5/2/e00047-14.full.pdf",
#             "http://citeseerx.ist.psu.edu/viewdoc/summary?doi=10.1.1.952.425"
#           ],
#           "year": 2016,
#           "doi": null,
#           "oai": "oai:CiteSeerX.psu:10.1.1.952.425",
#           "downloadUrl": "",
#           "pdfHashValue": null,
#           "documentType": null,
#           "documentTypeConfidence": null,
#           "citationCount": null,
#           "estimatedCitationCount": null,
#           "acceptedDate": null,
#           "depositedDate": 1475535600000,
#           "publishedDate": null,
#           "issn": null,
#           "crossrefDocument": null,
#           "magDocument": null
#         }
#       },
#       {
#         "_index": "articles_2019_06_05",
#         "_type": "article",
#         "_id": "105850562",
#         "_score": 19.113363,
#         "_source": {
#           "id": "105850562",
#           "authors": [
#             "The New Haven Coronavirus"
#           ],
#           "citations": [],
#           "contributors": [
#             "The Pennsylvania State University CiteSeerX Archives"
#           ],
#           "datePublished": "2016-09-11",
#           "deleted": "ALLOWED",
#           "description": "To the Editor\u2014Esper et al. present the discovery of a novel human coronavirus (HCoV) in young children and infants with respiratory tract disease in New Haven: HCoV-NH [1]. However, they also men-tion that the virus is very similar to HCoV-NL63, a virus that was identified previously in Amsterdam, The Netherlands [2]. De-spite this, the 2 studies by Esper et al. [1, 3] and an Editorial Commentary by Mc-Intosh [4] avoid usage of the name \u201cHCoV-NL63 \u201d while repeatedly claiming the dis-covery of a novel virus. To judge whether HCoV-NH is really a novel HCoV, a comparative analysis of HCoV-NH with a number of different fea-tures of established HCoVs should be per-formed. Examining the relatedness of ge-nome sequences is one facet of such an analysis. Unfortunately, limited data on the genome sequence for HCoV-NH are avail-able, but inspection of a 126-bp fragment clearly shows that all HCoV-NH isolates cluster together with the HCoV-NL63 Am-sterdam-1 strain (figure 3 in [1]). This re-sult strongly suggests that the viruses found by Esper et al. are New Haven isolates of HCoV-NL63. Moreover, the actual nucle-otide difference between the New Haven isolates (GenBank accession nos. AY870943\u2013 AY871008) and the HCoV-NL63 isolate Amsterdam-1 (GenBank accession no. NC _005831) is 0%\u20136%. This degree of differ-ence falls well within the range of genetic variation observed among different HCoV-NL63 isolates from Amsterdam [2]. We re-ported the presence of distinct HCoV-NL63 variants that apparently are cocirculating, as has been confirmed recently by Arden et al. [5] and Bastien et al. [6]. Esper et al. do not seem to dispute that HCoV-NH is very similar to HCoV-NL63. What then made them decide to claim the identification of a novel virus? The only argument mentioned is that the research project was initiated before the first arti-cle on HCoV-NL63 was published. Is that how it works in science? No\u2014only the first report can claim a novel scientific finding. In fact, for HCoV-NL63, Esper et al.\u2019s is the third article that claims its dis-covery. The identification of HCoV-NL63 was first announced in an article in Nature Medicine (which was published electron-ically on 21 March 2004 [2]), and an ar-ticle by Fouchier et al. in the Proceeding",
#           "fullText": null,
#           "fullTextIdentifier": "http://jid.oxfordjournals.org/content/192/2/350.full.pdf",
#           "identifiers": [
#             "oai:CiteSeerX.psu:10.1.1.864.1077",
#             null
#           ],
#           "journals": null,
#           "language": null,
#           "duplicateId": null,
#           "publisher": null,
#           "rawRecordXml": "<record><header><identifier>\n    \n      \n        oai:CiteSeerX.psu:10.1.1.864.1077</identifier><datestamp>\n        2016-09-11</datestamp>\n      </header><metadata><oai_dc:dc xmlns:oai_dc=\"http://www.openarchives.org/OAI/2.0/oai_dc/\" xmlns:dc=\"http://purl.org/dc/elements/1.1/\" xsi:schemaLocation=\"http://www.openarchives.org/OAI/2.0/oai_dc/ http://www.openarchives.org/OAI/2.0/oai_dc.xsd\" ><dc:title>\n      \n        \n          Correspondence Questions Concerning</dc:title><dc:creator>\n          The New Haven Coronavirus</dc:creator><dc:description>\n          To the Editor\u2014Esper et al. present the discovery of a novel human coronavirus (HCoV) in young children and infants with respiratory tract disease in New Haven: HCoV-NH [1]. However, they also men-tion that the virus is very similar to HCoV-NL63, a virus that was identified previously in Amsterdam, The Netherlands [2]. De-spite this, the 2 studies by Esper et al. [1, 3] and an Editorial Commentary by Mc-Intosh [4] avoid usage of the name \u201cHCoV-NL63 \u201d while repeatedly claiming the dis-covery of a novel virus. To judge whether HCoV-NH is really a novel HCoV, a comparative analysis of HCoV-NH with a number of different fea-tures of established HCoVs should be per-formed. Examining the relatedness of ge-nome sequences is one facet of such an analysis. Unfortunately, limited data on the genome sequence for HCoV-NH are avail-able, but inspection of a 126-bp fragment clearly shows that all HCoV-NH isolates cluster together with the HCoV-NL63 Am-sterdam-1 strain (figure 3 in [1]). This re-sult strongly suggests that the viruses found by Esper et al. are New Haven isolates of HCoV-NL63. Moreover, the actual nucle-otide difference between the New Haven isolates (GenBank accession nos. AY870943\u2013 AY871008) and the HCoV-NL63 isolate Amsterdam-1 (GenBank accession no. NC _005831) is 0%\u20136%. This degree of differ-ence falls well within the range of genetic variation observed among different HCoV-NL63 isolates from Amsterdam [2]. We re-ported the presence of distinct HCoV-NL63 variants that apparently are cocirculating, as has been confirmed recently by Arden et al. [5] and Bastien et al. [6]. Esper et al. do not seem to dispute that HCoV-NH is very similar to HCoV-NL63. What then made them decide to claim the identification of a novel virus? The only argument mentioned is that the research project was initiated before the first arti-cle on HCoV-NL63 was published. Is that how it works in science? No\u2014only the first report can claim a novel scientific finding. In fact, for HCoV-NL63, Esper et al.\u2019s is the third article that claims its dis-covery. The identification of HCoV-NL63 was first announced in an article in Nature Medicine (which was published electron-ically on 21 March 2004 [2]), and an ar-ticle by Fouchier et al. in the Proceedings</dc:description><dc:contributor>\n          The Pennsylvania State University CiteSeerX Archives</dc:contributor><dc:publisher>\n          </dc:publisher><dc:date>\n          2016-09-11</dc:date><dc:date>\n          2016-09-11</dc:date><dc:format>\n          application/pdf</dc:format><dc:type>\n          text</dc:type><dc:identifier>\n          http://citeseerx.ist.psu.edu/viewdoc/summary?doi=10.1.1.864.1077</dc:identifier><dc:source>\n          http://jid.oxfordjournals.org/content/192/2/350.full.pdf</dc:source><dc:language>\n          en</dc:language><dc:rights>\n          Metadata may be used without restrictions as long as the oai identifier remains attached to it.</dc:rights>\n        </oai_dc:dc>\n      </metadata>\n    </record>",
#           "relations": [],
#           "repositories": [
#             {
#               "id": "145",
#               "openDoarId": 0,
#               "name": "CiteSeerX",
#               "uri": null,
#               "urlHomepage": null,
#               "urlOaipmh": null,
#               "uriJournals": null,
#               "physicalName": "noname",
#               "source": null,
#               "software": null,
#               "metadataFormat": null,
#               "description": null,
#               "journal": null,
#               "roarId": 0,
#               "pdfStatus": null,
#               "nrUpdates": 0,
#               "disabled": false,
#               "lastUpdateTime": null,
#               "repositoryLocation": null
#             }
#           ],
#           "repositoryDocument": {
#             "pdfStatus": 0,
#             "textStatus": 0,
#             "metadataAdded": 1509409022000,
#             "metadataUpdated": 1529501836000,
#             "timestamp": 1473548400000,
#             "depositedDate": 1473548400000,
#             "indexed": 0,
#             "deletedStatus": "0",
#             "pdfSize": 0,
#             "tdmOnly": false,
#             "pdfOrigin": "http://jid.oxfordjournals.org/content/192/2/350.full.pdf"
#           },
#           "similarities": null,
#           "subjects": [
#             "text"
#           ],
#           "title": "Correspondence Questions Concerning",
#           "topics": [],
#           "types": [],
#           "urls": [
#             "http://jid.oxfordjournals.org/content/192/2/350.full.pdf",
#             "http://jid.oxfordjournals.org/content/192/2/350.full.pdf",
#             "http://citeseerx.ist.psu.edu/viewdoc/summary?doi=10.1.1.864.1077"
#           ],
#           "year": 2016,
#           "doi": null,
#           "oai": "oai:CiteSeerX.psu:10.1.1.864.1077",
#           "downloadUrl": "",
#           "pdfHashValue": null,
#           "documentType": null,
#           "documentTypeConfidence": null,
#           "citationCount": null,
#           "estimatedCitationCount": null,
#           "acceptedDate": null,
#           "depositedDate": 1473548400000,
#           "publishedDate": null,
#           "issn": null,
#           "crossrefDocument": null,
#           "magDocument": null
#         }
#       }
#     ]
#   }
# ]
